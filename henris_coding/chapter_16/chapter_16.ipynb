# %% [markdown]
# # Modeling Sequential Data Using Recurrent Neural Networks

# %% [markdown]
# In this chapter, we will explore **RNNs** and see their application in modeling sequential data and a specific subset of sequential data---time-series data.  In this chapter, we will cover the following topcis:
# - Introducing Sequential Data
# - RNNs for modeling sequences
# - Long Short-Term Memory (LSTM)
# - Truncated Backpropagation through time (T-BPTT)
# - Implementing a multilayer RNN for sequence modeling in TensorFlow
# - Project one: RNN sentiment analysis of the IMDb movie review dataset
# - Project two: RNN character-level language modeling with LSTM cells, using text data from Shakespeare's Hamlet
# - Using gradient clipping to avoid exploding gradients

# %% [markdown]
# ## Modeling sequential data---Order Matters
#
# What makes sequences unique from other data types is that elements in a sequence appear in a certain order, and are not independent of each other.  Order matters.
#
# ## Representing Sequences
#
# Throughout this chapter, we will represent sequences as $\left( \mathbf{x}^{(1)}, \mathbf{x}^{(2)}, \ldots, \mathbf{x}^{(T)} \right)$.  The superscript indices indicate the order of the instances, and the length of the sequence is $T$.
#
# The following figure shows and example of time-series data where both $x$'s and $y$'s naturally follow the order according to their time axis; therefore, both $x$'s and $y$'s are sequences:
#
# <img src="images/16_01.png" style="width:500px">
#
# RNNs are designed for modeling sequences and are capable of remembering past information and processing new events accordingly.
#
# ## The different categories of sequence modeling
#
# Sequence modeling has many fascinating applications, such as language translation, image captioning, and text generation.
#
# We need to uderstand the different types of sequence modeling tasks to develop an appropriate model.  The following figure shows several different relationship categories of input and output data:
# <img src="images/16_02.png" style="width:500px">
#
# If either the input or output data is a sequence, the data will form one of the following three different categories:
# - **Many-to-One**: The input data is a sequence, but the output is a fixed-size vector, not a sequence.  For example, in sentiment analysis, the input is text-bases and the output is a class label.
# - **One-to-Many**: The input data is in standard format, not a sequence, but the output is a sequence.  An example of this category is image captioning---the input is an image; the output is an English phrase.
# - **Many-to-Many**: Both the input and the output arrays are sequences.  This category can be further divided based on whether the input and output are synchronized or not.  An example of a **synchronized** many-to-many modeling task is video classification, where each frame in a vdeo is labeled.  An example of a **delayed** many-to-many modeling taks is translating a language into another language.  For instance, an entire English sentence must be read and processed by a machine before producing its translation into German.
#
# ## RNNs for modeling sequences
#
# In this section, now that we understand sequences, we can look at the foundations of RNNs.  We'll start by introducing the typical structure of an RNN, and we'll see how the data flows through it with one or more hidden layers.  We'll then examine how the neuron activations are computed in a typical RNN.  This will create a context for us to discuss the common challenges in training RNNs, and explore the modern solution to these challenges---LSTM.
#
# ## Understanding the structure and flow of an RNN
#
# <img src="images/16_03.png" style="width:500px">
# In a standard feedforward network, information flows from the input to the hidden layer, and then from the hidden layer to the output layer.  On the other hand, in a recurrent network, the hidden layer gets its input from both the input layer and the hidden layer from the previous time step.
#
# The folow of information in adjacent time steps in the hidden layer allows the network to have a memory of past events.  This flow of information is usually displayed as a loop, also known as a recurrent edge in graph notation, which is how this general architecture got its name.
#
# In the following figure, the single hedden layer network and the multilayer network illustrate two contrasting architectures:
#
# <img src="images/16_04.png" style="width:500px">
# In order to examine the architecture of RNNs and the flow of information, a compact representation with a recurrent edge can be unfolded, which you can see in the preceding figure.
#
# As we know, each hidden unit in a standard neural network receives only one input---the net preactivation associated with the input layer.  Now, in contrast, each hidden unit in an RNN receives two distinct sets of input---the preactivation from the input layer and the activation of the same hidden layer from the previous time step $(t-1)$.
#
# ## Computing activations in an RNN
#
# Now that we understand the structure and general flow of information in an RNN, let's get more specific and compute the actual activations of the hidden layers as well as the output layer.  For simplicity, we'll consider just a single hidden layer; however, the same concept applies to multilayer RNNs.
#
# Each directed edge (the connections between boxes) in the representation of an RNN that we just looked at is associated with a weight matrix.  Those weights do not depend on time $t$; therefore, they are shared across the time axis.  The different weight matrices in a single layer RNN are as follows:
# - $W_{xh}$: The weight matrix between the input $\mathbf{x}^{t}$ and the hidden layer $\mathbf{h}$.
# - $W_{hh}$: The weight matrix associated with the recurrent edge.
# - $W_{hy}$: The weight matrix between the hidden layer and the output layer.
#
# You can see these weight matrices in the following figure:
#
# <img src="images/16_05.png" style="width:500px">
#
# In certain implementations, you may observe that the weight matrices $\mathbf{W}_{xh}$ and $\mathbf{W}_{hh}$ are concatenated to a combined matrix $\mathbf{W}_h = \left[ \mathbf{W}_{xh}; \mathbf{W}_{hh} \right]$.  Later on, we will make use of this notation as well.
#
# Computing the activations is very similar to standard multilayer perceptrons, and other types of feedforward nerual networks.  For the hidden layer, the net input $\mathbf{z}_{h}$ (preactivation) is:
# $$
# \mathbf{z}_h^{(t)} = \mathbf{W}_{xh}\mathbf{x}^{(t)} + \mathbf{W}_{hh}\mathbf{h}^{(t-1)} + \mathbf{b}_h
# $$
#
# Then the activation of the hidden units at the time step $t$ are calculated as follows:
# $$
# \mathbf{h}^{(t)} = \phi_h\left( \mathbf{W}_{xh}\mathbf{x}^{(t)} + \mathbf{W}_{hh}\mathbf{h}^{(t-1)} + \mathbf{b}_h \right)
# $$
# where $\mathbf{b}_h$ is the bias vector for the hidden uniits, and $\phi_h(\cdot)$ is the activation function of the hidden layer.
#
# The activations of the output units will be computed as follows:
# $$
# \mathbf{y}^{(t)} = \phi_y\left( \mathbf{W}_{hy}\mathbf{h}^{(t)} + \mathbf{b}_y \right)
# $$
#
# To help clarify this further, the following figure shows the process of computing these activtions with both formulations:
#
# <img src="images/16_06.png" style="width:500px">
#
# ## The challenges of learning long-range interactions
#
# Backpropagation through time, or BPTT, which we briefly mentioned in the previous information box, introduces some new challenges.
#
# In computing the gradients of a loss function, the so-called **vanishing** or **exploding** gradient problem arises.  This problem is explained through the examples in the following figure, which shows an RNN with only one hidden unit for simplicity:
# <img src="images/16_07.png" style="width:500px">
#
# In practice, there are two solutions to this problem:
# - Truncated Backpropagation through time (TBPTT)
# - Long short-term memory (LSTM)
#
# TBPTT clips the gradients above a given threshold.  While TBPTT can solve the exploding gradient problem, the truncation limits the number of steps that the gradient can effectively flow back and properly update the weights.
#
# On the other hand, LSTM has been more succussful in modeling long-range sequences by overcoming the vanishing gradient problem.  Let us discuss the LSTM in more detail:

# %% [markdown]
# ## LSTM units
#
# The building block of an LSTM is a memory cell which essentially represents the hidden layer.
#
# In each memory cell, there is a recurrent edge that has the desirable weight $w=1$.  The values associated with this recurrent edge is called the **cell state**.  The unfolded structure of a modern LSTM is shown in the following figure:
#
# <img src="images/16_18.png" style="width:500px">
#
# Notice that the cell state from the previous time step, $\mathbf{C}^{(t-1)}$, is modified to get the cell state at the current time step, $\mathbf{C}^{(t)}$, without being multiplied directly with any weight factor.
#
# Notice that $\odot$ refers to the element-wise product, while $\oplus$ means element-wise summation.
#
# In the figure, four boxes are indicated with an activation function, either the sigmoid function ($\sigma$), or the hyperbolic tangent (tanh), and a set of weights.  These units of computation with sigmoid activation functions, whose output are passed through $\odot$ are called **gates**.
#
# In an LSTM cell, there are 3 different types of gates, known as the forget gate, the input gate, and the output gate:
# - The **forget gate** ($\mathbf{f}_t$), allows the memory cell to reset the cell sate, without growing indefintely.  In fact, the forget gate decides which information is allowed to go through and which information to suppress.
# $$
# \mathbf{f}_t = \sigma\left( \mathbf{W}_{xf}\mathbf{x}^{(t)} + \mathbf{W}_{hf}\mathbf{h}^{(t-1)} + \mathbf{b}_f \right)
# $$
# - The input gate ($\mathbf{i}_t$) and the input node ($\mathbf{g}_t$) are responsible for updating the cell state.  The are computed as follows:
# $$
# \mathbf{i}_t = \sigma\left( \mathbf{W}_{xi}\mathbf{x}^{(t)} + \mathbf{W}_{hi}\mathbf{h}^{(t-1)} + \mathbf{b}_i \right)
# $$
# $$
# \mathbf{g}_t = \tanh\left( \mathbf{W}_{xg}\mathbf{x}^{(t)} + \mathbf{W}_{hg}\mathbf{h}^{(t-1)} + \mathbf{b}_g \right)
# $$
#
# The cell state at time $t$ is then computed as follows:
# $$
# \mathbf{C}^{(t)} = \left( \mathbf{C}^{(t-1)}\odot\mathbf{f}_t \right)\oplus\left( \mathbf{i}_t\odot\mathbf{g}_t \right)
# $$
# - The output gate $\left( \mathbf{o}_t \right)$ decides how to update the values of the hidden units:
# $$
# \mathbf{o}_t = \tanh\left( \mathbf{W}_{xo}\mathbf{x}^{(t)} + \mathbf{W}_{ho}\mathbf{h}^{(t-1)} + \mathbf{b}_o \right)
# $$
# Given this, the hidden units at the current time step are computed as follows:
# $$
# \mathbf{h}^{(t)} = \mathbf{o}_{t}\odot\tanh\left( \mathbf{C}^{(t)} \right)
# $$

# %% [markdown]
# ## Implmenting a multilayer RNN for sequence modeling in TensorFlow
#
# Now that we introduced the underlying theory behind RNNs, we are ready to move on to the more practical part to implement RNNs in TensorFlow.  During this rest of this chapter, we will apply RNNs to 2 common problem tasks:
# 1. Sentiment analysis
# 2. Language modeling

# %% [markdown]
# ## Project one---performing sentiment analysis of IMDb movie reviews using multilayer RNNs
#
# In this section and the following subsections, we will implement a multilayer RNN for sentiment analysis using a many-to-one architecture.
#
# In the next section, we will implement a many-to-many RNN for an application of language modeling.

# %% [markdown]
# ## Preparing the data
#
# In the preprocessing steps in _Chapter 8_, we created a clean dataset named `movie_data.csv`, which we'll use again now.  So let us import the necessary modules and read the data into a pandas `DataFrame`, as follows:

# %%
import pyprind
import pandas as pd
from string import punctuation
import re
import numpy as np

# %%
df = pd.read_csv("movie_data.csv", encoding="utf-8")

# %% [markdown]
# Recall that this `df` data frame has 2 columns, name `'review'` and `'sentiment'`, where `'review'` contains the text of movie reviews and `'sentiment'` contains the `0` or `1` labels.  The text component of these movie reviews are sequences of words; therefore, we want to build an RNN model to process the words in each sequence, and at the end, classify the entire sequence to `0` or `1` classes.
#
# To prepare the data for input to a neural network, we need to encode it into numeric values.  To do this, we first find the unique words in the dataset, which can be done using sets in Python.  However, using sets for such a large dataset is _not_ efficient.  A more efficient way is to use `Counter` from the collections package.  The documentation for counter can be found at https://docs.python.org/3/library/collections.html#collections.Counter
#
# In the following code, we will define `counts` object from the `Counter` class that collects the counts of occurrence of each unique word in the text.  Note that in this particular application (and in contrast to the bag-of-words model), we are only interested in the set of unique words, and won't require the word counts, which are created as a side product.
#
# Then, we create a mapping in the form of a dictionary that maps each unique word, in our dataset, to a unique integer number.  We call this dictionary `word_to_int`, which can be used to convert the entire text of a review into a list of numbers.  The unique words are sorted based on their counts, but any any arbitary order can be used without affecting the final results.  This process of converting a text into a list of numbers is performed using the following code:

# %%
## Preprocessing the data: Separate the words and count each word's occurrence

from collections import Counter

counts = Counter()
pbar = pyprind.ProgBar(len(df["review"]), title="Counting words occurrences")
for i, review in enumerate(df["review"]):
    text = "".join([c if c not in punctuation else " "+c+" " for c in review]).lower()
    df.loc[i, "review"] = text
    pbar.update()
    counts.update(text.split())
# Out:
# Counting words occurrences
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:05:37

# %%
print(type(counts))
print(counts.get("the"))
# Out:
# <class 'collections.Counter'>
# 667950

# %%
## Create a mapping:  Map each unique word to an integer
word_counts = sorted(counts, key=counts.get, reverse=True)  # descending order
print(word_counts[:10])
word_to_int = {word: j for j, word in enumerate(word_counts, 1)}
print(word_to_int)
# Out:
# ['the', '.', ',', 'and', 'a', 'of', 'to', "'", '/', 'is']
# {'the': 1, '.': 2, ',': 3, 'and': 4, 'a': 5, 'of': 6, 'to': 7, "'": 8, '/': 9, 'is': 10, '>': 11, '<': 12, 'br': 13, 'it': 14, 'in': 15, 'i': 16, 'this': 17, 'that': 18, '-': 19, '"': 20, 's': 21, 'was': 22, 'as': 23, 'movie': 24, 'for': 25, 'with': 26, 'but': 27, 'film': 28, ')': 29, '(': 30, 'you': 31, 't': 32, 'on': 33, 'not': 34, 'he': 35, 'are': 36, 'his': 37, 'have': 38, 'one': 39, 'be': 40, '!': 41, 'all': 42, 'at': 43, 'they': 44, 'by': 45, 'an': 46, 'who': 47, 'so': 48, 'from': 49, 'like': 50, 'there': 51, 'or': 52, 'just': 53, 'her': 54, 'out': 55, 'about': 56, 'if': 57, 'has': 58, '?': 59, 'what': 60, 'some': 61, 'good': 62, 'can': 63, 'when': 64, 'more': 65, 'very': 66, 'she': 67, 'up': 68, 'no': 69, 'time': 70, 'my': 71, 'even': 72, 'would': 73, 'which': 74, 'only': 75, 'story': 76, 'really': 77, 'see': 78, 'their': 79, 'had': 80, 'me': 81, 'well': 82, 'we': 83, 'were': 84, ':': 85, 'than': 86, 'much': 87, 'bad': 88, 'get': 89, 'been': 90, 'other': 91, 'do': 92, 'people': 93, 'great': 94, 'will': 95, 'also': 96, 'into': 97, 'because': 98, 'how': 99, 'him': 100, 'first': 101, 'don': 102, 'most': 103, 'made': 104, 'its': 105, 'them': 106, 'then': 107, 'make': 108, 'way': 109, 'could': 110, 'too': 111, 'movies': 112, 'any': 113, 'after': 114, 'characters': 115, 'think': 116, 'watch': 117, '*': 118, 'character': 119, 'films': 120, 'two': 121, 'many': 122, ';': 123, 'seen': 124, 'being': 125, 'love': 126, 'plot': 127, 'never': 128, 'life': 129, 'acting': 130, 'where': 131, 'show': 132, 'did': 133, 'best': 134, 'know': 135, 'little': 136, 'over': 137, 'off': 138, 'ever': 139, 'man': 140, 'does': 141, 'your': 142, 'better': 143, 'end': 144, 'here': 145, 'scene': 146, 'still': 147, 'say': 148, 'these': 149, 'why': 150, 'scenes': 151, 'while': 152, 've': 153, 'something': 154, 'such': 155, 'm': 156, 'go': 157, 'should': 158, 'through': 159, 'back': 160, 'real': 161, 'those': 162, 'now': 163, 'thing': 164, 'watching': 165, 'actors': 166, 're': 167, 'doesn': 168, 'director': 169, 'years': 170, 'funny': 171, 'didn': 172, 'though': 173, 'old': 174, '10': 175, 'another': 176, 'work': 177, 'before': 178, 'actually': 179, 'nothing': 180, 'makes': 181, 'look': 182, 'find': 183, 'going': 184, 'new': 185, 'same': 186, 'lot': 187, 'every': 188, 'few': 189, 'again': 190, 'part': 191, '&': 192, 'world': 193, 'down': 194, 'cast': 195, 'us': 196, 'things': 197, 'want': 198, 'quite': 199, 'pretty': 200, 'horror': 201, 'around': 202, 'seems': 203, 'young': 204, 'take': 205, 'big': 206, 'however': 207, 'got': 208, 'thought': 209, 'fact': 210, 'enough': 211, 'long': 212, 'both': 213, 'give': 214, 'may': 215, 'own': 216, 'between': 217, 'comedy': 218, 'series': 219, 'must': 220, 'right': 221, 'action': 222, 'music': 223, 'without': 224, 'guy': 225, 'times': 226, 'saw': 227, 'original': 228, 'always': 229, 'isn': 230, 'come': 231, 'role': 232, 'almost': 233, 'gets': 234, 'interesting': 235, 'point': 236, 'done': 237, 'whole': 238, 'least': 239, 'far': 240, 'bit': 241, 'd': 242, 'script': 243, 'family': 244, 'minutes': 245, 'feel': 246, '2': 247, 'might': 248, 'll': 249, 'making': 250, 'anything': 251, 'since': 252, 'am': 253, 'last': 254, 'tv': 255, 'probably': 256, 'performance': 257, 'kind': 258, 'away': 259, 'girl': 260, 'yet': 261, 'fun': 262, 'anyone': 263, 'woman': 264, 'worst': 265, 'sure': 266, 'rather': 267, 'hard': 268, 'day': 269, 'each': 270, 'played': 271, 'found': 272, 'looking': 273, 'screen': 274, 'our': 275, 'although': 276, 'especially': 277, 'believe': 278, 'dvd': 279, 'having': 280, 'trying': 281, 'course': 282, 'everything': 283, 'set': 284, 'goes': 285, 'book': 286, 'put': 287, 'ending': 288, 'comes': 289, 'maybe': 290, 'place': 291, 'let': 292, 'shows': 293, 'three': 294, 'worth': 295, 'different': 296, 'actor': 297, 'once': 298, 'main': 299, 'sense': 300, 'someone': 301, 'american': 302, 'reason': 303, 'play': 304, 'effects': 305, 'looks': 306, 'true': 307, 'money': 308, 'watched': 309, 'everyone': 310, 'year': 311, 'wa ...

# %%
a = [word for word in df.loc[1, "review"].split()]
# print(a)
# print(df.loc[1, "review"])

# %%
mapped_reviews = []
pbar = pyprind.ProgBar(len(df['review']), title="Map reviews to ints")
for review in df["review"]:
    mapped_reviews.append([word_to_int[word] for word in review.split()])
    pbar.update()
# Out:
# Map reviews to ints
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02

# %%
print(mapped_reviews[:2])
# Out:
# [[15, 5646, 3, 1, 2160, 3977, 26959, 30, 4824, 1575, 29, 1133, 7, 1, 316, 19, 720, 1612, 6, 6653, 753, 3, 14781, 3, 8680, 2, 33, 1, 14782, 328, 3, 3612, 6, 2105, 3, 67, 22, 1947, 15, 1, 8755, 6, 54, 339, 4, 54, 602, 4712, 15343, 2, 1732, 19, 121, 170, 323, 3, 1, 565, 953, 25748, 30, 1464, 19622, 29, 3, 47, 10, 5, 1121, 1099, 1362, 18, 58, 3040, 15, 6002, 25, 44343, 15, 716, 2, 1544, 2, 5290, 3192, 4, 1670, 7, 21518, 3, 1103, 7, 3921, 1, 434, 26, 37, 1956, 1801, 2333, 30, 3679, 3294, 29, 26, 1, 1285, 6, 507, 5, 286, 2, 1, 5463, 10558, 4, 92, 34, 2568, 106, 3, 27, 26, 1, 1457, 6, 1, 5056, 1362, 1320, 8833, 30, 623, 12704, 29, 18, 22, 15, 2762, 6, 1, 3488, 15, 1, 1358, 8, 21, 3, 44, 1873, 1, 1795, 4, 5, 5000, 6, 661, 4, 308, 7, 999, 1, 602, 2, 12, 13, 9, 11, 12, 13, 9, 11, 20, 602, 15, 14781, 20, 10, 5, 62, 255, 24, 3, 26, 1, 307, 76, 6, 5, 602, 6, 5, 3521, 170, 174, 260, 18, 22, 2373, 45, 5, 3041, 2160, 654, 412, 22, 5, 3129, 2, 1, 976, 4, 994, 244, 347, 79, 2413, 7, 999, 1, 602, 25, 65, 86, 1732, 170, 2, 207, 3, 5, 39815, 1362, 4, 6200, 63257, 15, 6002, 22, 495, 7, 24719, 99, 1, 4457, 830, 22, 2373, 2, 1, 926, 293, 1, 3488, 6, 953, 4, 1, 254, 498, 6, 3977, 15, 4253, 3, 27, 51, 10, 5, 588, 6, 1, 1430, 15, 1, 12170, 2, 71, 2071, 10, 1589, 2, 12, 13, 9, 11, 12, 13, 9, 11, 436, 30, 3535, 29, 85, 34, 1309], [589, 2, 2, 2, 48, 2, 2, 2, 16, 77, 50, 7431, 7487, 4, 37, 679, 776, 184, 2826, 6, 427, 15, 37, 112, 2, 611, 58, 1649, 100, 26, 37, 1761, 3012, 376, 1711, 414, 4, 35, 95, 2098, 5, 146, 8080, 2, 27, 3, 8517, 10, 37, 18183, 2, 3959, 51063, 3, 17, 22, 5, 88, 24, 41, 12, 13, 9, 11, 12, 13, 9, 11, 16, 220, 214, 3496, 7, 1, 643, 4, 4, 1, 166, 3, 599, 7431, 3, 25, 281, 79, 39816, 7, 108, 300, 49, 17, 2770, 3, 1473, 76, 41, 634, 6, 14, 104, 300, 4, 7431, 256, 172, 8, 32, 402, 14, 366, 4, 35, 22, 53, 184, 159, 1, 7381, 1414, 301, 73, 231, 68, 7, 100, 4, 395, 100, 60, 14, 22, 42, 56, 41, 12, 13, 9, 11, 12, 13, 9, 11, 16, 102, 8, 32, 476, 18, 310, 33, 17, 24, 22, 422, 55, 6, 126, 25, 1, 1144, 3, 52, 61, 155, 1862, 2, 2, 2, 16, 8, 153, 124, 376, 349, 112, 18, 80, 5, 127, 25, 3784, 2174, 41, 17, 80, 634, 3, 51064, 3, 13761, 3, 31679, 3, 1981, 6, 303, 2, 2, 2, 5, 613, 469, 6, 62, 644, 3, 1321, 4, 3663, 41, 12, 13, 9, 11, 12, 13, 9, 11, 16, 1590, 17, 431, 6, 1196, 25, 5, 3223, 3, 4, 16, 198, 71, 308, 160, 41, 16, 198, 71, 247, 641, 160, 16, 7841, 33, 17, 1248, 1211, 469, 6, 71, 70, 41, 102, 8, 32, 117, 17, 24, 3, 52, 469, 324, 794, 6, 142, 4781, 70, 152, 2763, 159, 5, 680, 131, 14, 8, 21, 413, 52, 72, 860, 68, 1, 434, 18, 10, 2432, 1, 279, 41, 278, 81, 3, 31, 8, 249, 1359, 81, 25, 1, 1980, 41]]

# %% [markdown]
# There is however one issue that we still need to solve---the sequences currently have different lengths.  In order to generate input data that is compatible with our RNN architecture, we will need to make sure that all the sequences have the same length.
#
# For this purpose, we define a parameter called `sequence_length` that we set to 200.  Sequences that have than 200 words will be left-padded with zeros.  Vice versa, sequences that are longer than 200 words are cut such that only the last 200 corresponding words will be used.  We can implement this preprocessing step in two steps:
# 1. Create a matrix of zeros, where each row corresponds to a sequence of size 200.
# 2. Fill the index of words in each sequence from the right-hand side of the matrix.  Thus, if a sequence has a length of 150, the first 50 elements of the corresponding row will stay zero.
#
# These 2 steps are shown in the following figure, for a small example with 8 sequences of sizes 4, 12, 8, 11, 7, 3, 10, 13.
#
# <img src="images/16_09.png" style="width:500px">
#
# Note that `sequence_length` is, in fact, a hyperparameter, and can be tuned for optimal performance.  We encourage you to fine-tune this parameter with different values, such as 50, 100, 200, 250, and 300.
#
# Check out the following code for the implementation of these steps to create sequences of the same length:

# %%
# Define same-length sequences.
# If the sequence length < 200:  left-pad with zeros.
# If the sequence length > 200:  use the LAST 200 elements.

sequence_length = 200  # known as T in our RNN formulas.
sequences = np.zeros((len(mapped_reviews), sequence_length), dtype=int)

for i, row in enumerate(mapped_reviews):
    review_arr = np.array(row)
    sequences[i, -1*len(row):] = review_arr[-1*sequence_length:]

# %% [markdown]
# After we preprocess the dataset, we can proceed with splitting the data into separate training and test sets.  Since the dataset was already shuffled, we can simply take the first half of the dataset for training, and the second half for testing, as follows:

# %%
X_train = sequences[:25000, :]
y_train = df.loc[:25000, "sentiment"].values
X_test = sequences[25000:, :]
y_test = df.loc[25000:, "sentiment"].values

# %% [markdown]
# Now, if we want to separate the dataset for cross-validation, we can further split the second half of the data further to generate a smaller test set and a validation set for hyperparameter optimization.
#
# Finally, we define a helper function that breaks a given dataset (which could be a training set or test set) into chunks, and returns a generator to iterate through these chunks (also known as mini-batches):

# %%
np.random.seed(123)  # for reproducibility

# Define a function to generate mini-batches:
def create_batch_generator(x, y=None, batch_size=64):
    n_batches = len(x)//batch_size
    x = x[:n_batches*batch_size]
    if y is not None:
        y = y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        if y is not None:
            yield x[ii:ii+batch_size], y[ii:ii+batch_size]
        else:
            yield x[ii:ii+batch_size]

# %% [markdown]
# Using generators, as we've done in this code, is a very useful technique for handling memory limitations.  This is the recommended approach for splitting the dataset into mini-batches for training a neural network, rather than creating all the data splits upfront and keeping them in memory during training.

# %% [markdown]
# ## Embedding
#
# During the data preparation in the previous step, we generated sequences of the same length.  The elements of these sequences were integer numbers that corresponded to the _indices_ of unique words.
#
# These words indices can be converted into input features in several different ways.  One naïve way is to apply one-hot encoding to convert indices into vectors of zeros and ones.  Then each word will be mapped to a vector whose size is the number of unique words in the entire dataset.  But a model trained on such features may suffer from the **curse of dimensionality**.  Furthermore, these features are very sparse, since all are zero except one.
#
# A more elegant way is to map each word to a vector of fixed size with real-valued elements (not necessarily integers).  In contrast to the one-hot encoded vectors, we can use finite-sized vectors to represent an infinite amount of real numbers (in theory, we can extract infinite real numbers from a given interval, for example $[-1,1]$).
#
# This is the idea behind embedding, which is a feature-learning technique to automatically learn the salient features to represent the words in our dataset.  Given the number of unique words _unique\_words_, we can choose the size of the embedding vectors to be much smaller than the number of unique words to represent the entire vocabulary.
#
# The advantages of embedding over one-hot encoding are as follows:
# - A reduction in the dimensionality of the feature space to decrease the effect of the curse of dimensionality.
# - The extraction of salient features since the embedding layer in a neural network is trainable.
#
# The following schematic representation shows how embedding works by mapping vocabulary indices to a trainable embedding matrix:
#
# <img src="images/16_10.png" style="width:500px">
#
# TensorFlow implements an efficient function, `tf.nn.embedding_lookup` that maps each integer that corresponds to a unique word, to a row of this trainable matrix.  For example, integer 1 is mapped to the first row, integer 2 is mapped to the second row, and so on.  Then, given a sequence of integers, such as $[0, 5, 3, 4, 19, 2, \ldots]$, we need to look up the corresponding rows for each element of this sequence.

# %% [markdown]
# Now, let us see how we can create an embedding layer in practice.  If we have `tf_x` as the input layer where the corresponding vocabulary indices are fed with type `tf.int32`, then creating an embedding layer can be done in two ste3ps, as follows:
# 1. We start by creating a matrix of size $[\mathrm{n\_words}\times\mathrm{embedding\_size}]$ as a tensor variable, which we call embedding, and we initialise its elements randomly with floats between $[-1, 1]$:
# ```python
# embedding = tf.Variable(tf.random_uniform(shape=(n_words, embedding_size), minval=-1, maxval=1))
# ```
# 2. Then, we use the `tf.nn.embedding_lookup` function to look up the row in the embedding matrix associated with each element of `tf_x`:
# ```python
# embed_x = tf.nn.embedding_lookup(embedding, tf_x)
# ```
#
# Notice that `tf.nn.embedding_lookup` requires 2 mandatory arguments: the embedding tensor, and the lookup IDs.

# %% [markdown]
# ## Building an RNN model
#
# Now we're ready to build an RNN model.  We'll implement a `SentimentRNN` class that has the following methods:
# - A constructor to set all the model parameters, and then create a computation graph, and call the `self.build` method to build the multilayer RNN model.
# - A `build` method that declares three placeholders for input data, input labels, and the keep probability for the dropout configuration of the hidden layer.  After declaring these, it creates an embedding layer, and builds the multilayer RNN using the embedded representation as the input.
# - A `train` method that creates a TensorFlow session for launching the computation graph, iterates through the mini-batches of data, and runs for a fixed number of epochs, to minimise the cost function defined in the graph.  This method also saves the model after 10 epochs for checkpointing.
# - A `predict` method that creates a new session, restores the last checkpoint saved during the training process, and carries out the predictions for the test data.
#
# In the following code, we'll see the implementation of this class and its methods broken into separate code sections.

# %% [markdown]
# ## The SentimentRNN class Constructor
#
# Let us start with the constructor of our `SentimentRNN` class, which we'll code as follows:

# %%
import tensorflow as tf

class SentimentRNN(object):
    def __init__(self, n_words, seq_len=200, lstm_size=256, num_layers=1,
                batch_size=64, learning_rate=0.0001, embed_size=200):
        self.n_words = n_words
        self.seq_len = seq_len
        self.lstm_size = lstm_size  # the number of hidden units
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.embed_size = embed_size
        
        self.g = tf.Graph()
        with self.g.as_default():
            tf.set_random_seed(123)
            self.build()
            self.saver = tf.train.Saver()
            self.init_op = tf.global_variables_initializer()
    
    """Please refer to the Markdown cell below: 'The build method'"""
    def build(self):
        # Define the placeholders
        tf_x = tf.placeholder(tf.int32, shape=(self.batch_size, self.seq_len), name="tf_x")
        tf_y = tf.placeholder(tf.float32, shape=(self.batch_size), name="tf_y")
        tf_keepprob = tf.placeholder(tf.float32, name="tf_keepprob")
        
        # Creating the embedding layer
        embedding = tf.Variable(tf.random_uniform((self.n_words, self.embed_size), minval=-1, maxval=1),
                               name="embedding")
        embed_x = tf.nn.embedding_lookup(embedding, tf_x, name='embedded_x')
        
        # Define the LSTM cell and stack them together  tf.nn.rnn_cell.LSTMCell
        cells = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(
        self.lstm_size), output_keep_prob=tf_keepprob) for i in range(self.num_layers)])
        
        # Define the initial state:
        self.initial_state = cells.zero_state(self.batch_size, tf.float32)
        print('  << initial state >>  ', self.initial_state)
        lstm_outputs, self.final_state = tf.nn.dynamic_rnn(cells, embed_x, initial_state=self.initial_state)
        
        # Note: lstm_outputs shape = [batch_size, max_time, cells.output_size]
        print("\n << lstm_output >> ", lstm_outputs)
        print("\n << final state >> ", self.final_state)
        
        logits = tf.layers.dense(inputs=lstm_outputs[:, -1], units=1, activation=None, name="logits")
        
        logits = tf.squeeze(logits, name="logits_squeezed")
        print("\n << logits >> ", logits)
        
        y_proba = tf.nn.sigmoid(logits, name="probabilities")
        predictions = {"probabilities": y_proba,
                      "labels": tf.cast(tf.round(y_proba), tf.int32, name="labels")}
        print("\n << predictions >> ", predictions)
        
        # Define the cost function
        cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf_y, logits=logits), name="cost")
        
        # Define the optimizer
        optimizer = tf.train.AdamOptimizer(self.learning_rate)
        train_op = optimizer.minimize(cost, name="train_op")
    
    def train(self, X_train, y_train, num_epochs):
        with tf.Session(graph=self.g) as sess:
            sess.run(self.init_op)
            iteration = 1
            for epoch in range(num_epochs):
                state = sess.run(self.initial_state)
                
                for batch_x, batch_y in create_batch_generator(X_train, y_train, self.batch_size):
                    feed = {"tf_x:0": batch_x, "tf_y:0": batch_y, "tf_keepprob:0": 0.5, self.initial_state: state}
                    loss, _, state = sess.run(["cost:0", "train_op", self.final_state], feed_dict=feed)
                    
                    if not iteration % 20:
                        print("Epoch: {}/{} Iteration: {} | Train loss: {:.5f}".format(epoch + 1,
                                                                                       num_epochs,
                                                                                       iteration,
                                                                                       loss))
                    iteration += 1
                if not (epoch + 1) % 10:
                    self.saver.save(sess, "model/sentiment-{}.ckpt".format(epoch))
    
    def predict(self, X_data, return_proba=False):
        preds = []
        with tf.Session(graph=self.g) as sess:
            self.saver.restore(sess, tf.train.latest_checkpoint("./model/"))
            test_state = sess.run(self.initial_state)
            for ii, batch_x in enumerate(create_batch_generator(X_data, None, batch_size=self.batch_size), 1):
                feed = {"tf_x:0": batch_x, "tf_keepprob:0": 1.0, self.initial_state: test_state}
                if return_proba:
                    pred, test_state = sess.run(["probabilities:0", self.final_state], feed_dict=feed)
                else:
                    pred, test_state = sess.run(["labels:0", self.final_state], feed_dict=feed)
                
                preds.append(pred)
        
        return np.concatenate(preds)

# %% [markdown]
# - `n_words` must be set equal to the number of unique words (plus 1 since we use zero to fill sequences whose size is less than 200).  It is used while creating the embedding layer along with the `embed_size` hyperparameter.
# - `seq_len` variable must be set according to the length of the sequences that were created in the preprocessing steps we went through previously.
# - `lstm_size` is another hyperparameter that determines the number of hidden units in each RNN layer.

# %% [markdown]
# ## The build method
#
# Next, let us discuss the `build` method for our `SentimentRNN` class.  This is the longest and most critical method in our sequence, so we'll be going through it in plenty of detail.  First we'll look at the code in full, so we can see the whole picture, and then we'll analyze each of its main parts.
#
# So first of all in our `build` method here, we created three placeholders, namely `tf_x`, `tf_y`, and `tf_keepprob`, which we need for feeding the input data.  Then we aded the embedding layer, which builds the embedded representation `embed_x`, as we discussed earlier.
#
# Next, in our `build` method, we built the RNN network with LSTM cells.  We did this in three steps:
# 1. First, we defined the multilayer RNN cells.
# 2. Next, we defined the initial state for these cells.
# 3. Finally, we created an RNN specified by the RNN cells and their initial states.
#
# Let's break these three steps out in deail in the following three sections, so we can examine in depth how we built the RNN network in our `build` method.

# %% [markdown]
# ### Step 1---Defining multilayer RNN cells.
#
# To examine how we coded our `build` method to build the RNN network, the first step was to define our multilayer RNN cells.
#
# Fortunately, TensorFlow has a very nice wrapper class to define LSTM cells---the `BasicLSTMCell` class---which can be stacked together to from a multilayer RNN using the `MultiRNNCell` wrapper class.  The process of stacking RNN cells with a dropout has three nested steps; these three nested steps can be described from the inside out as follows:
# 1. First, create the RNN cells using `tf.contrib.rnn.BasicLSTMCell`.
# 2. Apply the dropout to the RNN cells using `tf.contrib.rnn.DropoutWrapper`.
# 3. Make a list of such cells according to the desired number of RNN layers, and pass this list to `tf.contrib.rnn.MultiRNNCell`.
#
# In our `build` method code, this list is created using Python list comprehension.  Note that for a single layer, this list has oly one cell.

# %% [markdown]
# ### Step 2---Defining the initial states for the RNN cells.
#
# The second step that our `build` method takes to build the RNN network was to define the initial states for the RNN cells.
#
# You will recall from the architecture of LSTM cells, there are 3 types of inputs in an LSTM cell---input data $\mathbf{x}^{(t)}$, activations of hidden units from the previous time step $\mathbf{h}^{(t-1)}$, and the cell state from the previous time step $\mathbf{C}^{(t-1)}$.
#
# Therefore, in our `build` method implementation, $\mathbf{x}^{(t)}$ is the embedded `embed_x` data tensor.  When we start processing a new input sequence, we initialize the cell states to zero state; then after each time step we need to store the updated state of the cells to use for the next time step.
#
# Once our multilayer RNN object is defined (`cells` in our implementation), we define its initial state in our `build` method using the `cells.zero_state` method.

# %% [markdown]
# ### Step 3---Creating the RNN using the RNN cells and their states.
#
# The third step to creating the RNN in our `build` method, used the `tf.nn.dynamic_rnn` function to pull together all our components.
#
# The `tf.nn.dynamic_rnn` function therefore pulls the embedded data, the RNN cells, and their initial states, and creates a pipeline for them according to the unrolled architecture of LSTM cells.
#
# The `tf.nn.dynamic_rnn` functionreturns a tuple containing the activations of the RNN cells, `outputs`; and their final states, `state`.  The output is a three-dimensional tensor with the shape `(batch_size, num_steps, lstm_size)`.  We pass `outputs` to a fully connected layer to get logits, and we store the final state to use as the initial state of the next mini-batch of data.
#
# Finally, in our build method, after setting up the RNN components of the network, the cost function and optimization schemes can be defined like any other neural network.

# %% [markdown]
# ## The train method
#
# The next method in our `SentimentRNN` class is `train`.  This method is quite similar to the train methods we created in _Chapter 14_ and _Chapter 15_, except that we have an additional tensor, `state`, that we feed into our network.
#
# The code above shows the implementation of the `train` method...
#
# In this implementation of our `train` method, at the beginning of each epoch, we start from the zero states of RNN cells as our current state.  Running each mini-batch of data is performed by feeding the current state along with the data `batch_x` and their labels `batch_y`.  Upon finishing the execution of a mini-batch, we update the state to be the final state, which is returned by the `tf.nn.dynamic_rnn` function.  This updated state will be used toward execution of the next mini-batch.  This process is repeated and the current state is updated throughout the epoch.

# %% [markdown]
# ## The predict method
#
# Finally, the last method in our `SentimentRNN` class is the `predict` method, which keeps updating the current state similar to the `train` method, shown in the code above...

# %% [markdown]
# ## Instantiating the SentimentRNN class
#
# We've now coded and examined all four parts of our `SentimentRNN` class, which were the class constructor, the `build` method, the `train` method, and the `predict` method.
#
# We are now ready to create an object of the class `SentimentRNN`, with parameters as follows:

# %%
n_words = max(list(word_to_int.values())) + 1

rnn = SentimentRNN(n_words=n_words,
                  seq_len=sequence_length,
                  embed_size=256,
                  lstm_size=128,
                  num_layers=1,
                  batch_size=100,
                  learning_rate=0.001)
# Out:
#   << initial state >>   (LSTMStateTuple(c=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros:0' shape=(100, 128) dtype=float32>, h=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1:0' shape=(100, 128) dtype=float32>),)
#
#  << lstm_output >>  Tensor("rnn/transpose_1:0", shape=(100, 200, 128), dtype=float32)
#
#  << final state >>  (LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_3:0' shape=(100, 128) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_4:0' shape=(100, 128) dtype=float32>),)
#
#  << logits >>  Tensor("logits_squeezed:0", shape=(100,), dtype=float32)
#
#  << predictions >>  {'probabilities': <tf.Tensor 'probabilities:0' shape=(100,) dtype=float32>, 'labels': <tf.Tensor 'labels:0' shape=(100,) dtype=int32>}

# %% [markdown]
# Notice here that we use `num_layers=1` to use a single RNN layer.  Although our implementation allows us to create multilayer RNNs, by setting `num_layers` greater than 1.  Here we should consider the small size of our dataset, and that a single RNN may generalise better to unseen data, since it is less likely to overfit the training data.

# %% [markdown]
# ## Training and optimising the sentiment analysis RNN model
#
# Next, we can train the RNN model by calling the `rnn.train` function.  In the following code, we train the model for `40` epochs, using the input from `X_train` and the corresponding class labels stored in `y_train`:

# %%
rnn.train(X_train, y_train, num_epochs=40)
# Out:
# Epoch: 1/40 Iteration: 20 | Train loss: 0.70071
# Epoch: 1/40 Iteration: 40 | Train loss: 0.63536
# Epoch: 1/40 Iteration: 60 | Train loss: 0.67273
# Epoch: 1/40 Iteration: 80 | Train loss: 0.57852
# Epoch: 1/40 Iteration: 100 | Train loss: 0.55505
# Epoch: 1/40 Iteration: 120 | Train loss: 0.53757
# Epoch: 1/40 Iteration: 140 | Train loss: 0.59300
# Epoch: 1/40 Iteration: 160 | Train loss: 0.48948
# Epoch: 1/40 Iteration: 180 | Train loss: 0.52614
# Epoch: 1/40 Iteration: 200 | Train loss: 0.55652
# Epoch: 1/40 Iteration: 220 | Train loss: 0.40346
# Epoch: 1/40 Iteration: 240 | Train loss: 0.46770
# Epoch: 2/40 Iteration: 260 | Train loss: 0.49523
# Epoch: 2/40 Iteration: 280 | Train loss: 0.43171
# Epoch: 2/40 Iteration: 300 | Train loss: 0.40109
# Epoch: 2/40 Iteration: 320 | Train loss: 0.43319
# Epoch: 2/40 Iteration: 340 | Train loss: 0.45512
# Epoch: 2/40 Iteration: 360 | Train loss: 0.30557
# Epoch: 2/40 Iteration: 380 | Train loss: 0.41766
# Epoch: 2/40 Iteration: 400 | Train loss: 0.36661
# Epoch: 2/40 Iteration: 420 | Train loss: 0.39098
# Epoch: 2/40 Iteration: 440 | Train loss: 0.35926
# Epoch: 2/40 Iteration: 460 | Train loss: 0.53615
# Epoch: 2/40 Iteration: 480 | Train loss: 0.32861
# Epoch: 2/40 Iteration: 500 | Train loss: 0.29157
# Epoch: 3/40 Iteration: 520 | Train loss: 0.30381
# Epoch: 3/40 Iteration: 540 | Train loss: 0.27718
# Epoch: 3/40 Iteration: 560 | Train loss: 0.34324
# Epoch: 3/40 Iteration: 580 | Train loss: 0.26217
# Epoch: 3/40 Iteration: 600 | Train loss: 0.22801
# Epoch: 3/40 Iteration: 620 | Train loss: 0.26769
# Epoch: 3/40 Iteration: 640 | Train loss: 0.26834
# Epoch: 3/40 Iteration: 660 | Train loss: 0.22248
# Epoch: 3/40 Iteration: 680 | Train loss: 0.27033
# Epoch: 3/40 Iteration: 700 | Train loss: 0.21202
# Epoch: 3/40 Iteration: 720 | Train loss: 0.21872
# Epoch: 3/40 Iteration: 740 | Train loss: 0.26403
# Epoch: 4/40 Iteration: 760 | Train loss: 0.24720
# Epoch: 4/40 Iteration: 780 | Train loss: 0.24038
# Epoch: 4/40 Iteration: 800 | Train loss: 0.28479
# Epoch: 4/40 Iteration: 820 | Train loss: 0.31957
# Epoch: 4/40 Iteration: 840 | Train loss: 0.28081
# Epoch: 4/40 Iteration: 860 | Train loss: 0.23338
# Epoch: 4/40 Iteration: 880 | Train loss: 0.31353
# Epoch: 4/40 Iteration: 900 | Train loss: 0.20387
# Epoch: 4/40 Iteration: 920 | Train loss: 0.25800
# Epoch: 4/40 Iteration: 940 | Train loss: 0.20897
# Epoch: 4/40 Iteration: 960 | Train loss: 0.21455
# Epoch: 4/40 Iteration: 980 | Train loss: 0.16293
# Epoch: 4/40 Iteration: 1000 | Train loss: 0.14185
# Epoch: 5/40 Iteration: 1020 | Train loss: 0.18330
# Epoch: 5/40 Iteration: 1040 | Train loss: 0.15744
# Epoch: 5/40 Iteration: 1060 | Train loss: 0.17438
# Epoch: 5/40 Iteration: 1080 | Train loss: 0.19249
# Epoch: 5/40 Iteration: 1100 | Train loss: 0.12055
# Epoch: 5/40 Iteration: 1120 | Train loss: 0.11850
# Epoch: 5/40 Iteration: 1140 | Train loss: 0.16578
# Epoch: 5/40 Iteration: 1160 | Train loss: 0.05172
# Epoch: 5/40 Iteration: 1180 | Train loss: 0.06648
# Epoch: 5/40 Iteration: 1200 | Train loss: 0.10943
# Epoch: 5/40 Iteration: 1220 | Train loss: 0.02965
# Epoch: 5/40 Iteration: 1240 | Train loss: 0.14564
# Epoch: 6/40 Iteration: 1260 | Train loss: 0.21675
# Epoch: 6/40 Iteration: 1280 | Train loss: 0.05008
# Epoch: 6/40 Iteration: 1300 | Train loss: 0.07317
# Epoch: 6/40 Iteration: 1320 | Train loss: 0.13078
# Epoch: 6/40 Iteration: 1340 | Train loss: 0.06158
# Epoch: 6/40 Iteration: 1360 | Train loss: 0.05605
# Epoch: 6/40 Iteration: 1380 | Train loss: 0.14764
# Epoch: 6/40 Iteration: 1400 | Train loss: 0.16773
# Epoch: 6/40 Iteration: 1420 | Train loss: 0.14218
# Epoch: 6/40 Iteration: 1440 | Train loss: 0.07672
# Epoch: 6/40 Iteration: 1460 | Train loss: 0.15024
# Epoch: 6/40 Iteration: 1480 | Train loss: 0.08742
# Epoch: 6/40 Iteration: 1500 | Train loss: 0.07780
# Epoch: 7/40 Iteration: 1520 | Train loss: 0.10116
# Epoch: 7/40 Iteration: 1540 | Train loss: 0.02525
# Epoch: 7/40 Iteration: 1560 | Train loss: 0.28765
# Epoch: 7/40 Iteration: 1580 | Train loss: 0.15521
# Epoch: 7/40 Iteration: 1600 | Train loss: 0.03583
# Epoch: 7/40 Iteration: 1620 | Train loss: 0.20546
# Epoch: 7/40 Iteration: 1640 | Train loss: 0.04796
# Epoch: 7/40 Iteration: 1660 | Train loss: 0.01674
# Epoch: 7/40 Iteration: 1680 | Train loss: 0.01694
# Epoch: 7/40 Iteration: 1700 | Train loss: 0.02852
# Epoch: 7/40 Iteration: 1720 | Train loss: 0.03252
# Epoch: 7/40 Iteration: 1740 | Train loss: 0.07748
# Epoch: 8/40 Iteration: 1760 | Train loss: 0.05935
# Epoch: 8/40 Iteration: 1780 | Train loss: 0.04865
# Epoch: 8/40 Iteration: 1800 | Train loss: 0.12522
# Epoch: 8/40 Iteration: 1820 | Train loss: 0.09605
# Epoch: 8/40 Iteration: 1840 | Train loss: 0.04653
# Epoch: 8/40 Iteration: 1860 | Train loss: 0.10674
# Epoch: 8/40 Iteration: 1880 | Train loss: 0.17348
# Epoch: 8/40 Iteration: 1900 | Train loss: 0.07237
# Epoch: 8/40 Iteration: 1920 | Train loss: 0.06813
# Epoch: 8/40 Iteration: 1940 | Train loss: 0.06747
# Epoch: 8/40 Iteration: 1960 | Train loss: 0.14743
# Epoch: 8/40 Iteration: 1980 | Train loss: 0.05305
# Epoch: 8/40 Iteration: 2000 | Train loss: 0.02611
# Epoch: 9/40 Iteration: 2020 | Train loss: 0.07653
# Epoch: 9/40 Iteration: 2040 | Train loss: 0.01450
# Epoch: 9/40 Iteration: 2060 | Train loss: 0.14059
# Epoch: 9/40 Iteration: 2080 | Train loss: 0.09871
# Epoch: 9/40 Iteration: 2100 | Train loss: 0.01415
# Epoch: 9/40 Iteration: 2120 | Train loss: 0.08295
# Epoch: 9/40 Iteration: 2140 | Train loss: 0.00779
# Epoch: 9/40 Iteration: 2160 | Train loss: 0.01035
# Epoch: 9/40 Iteration: 2180 | Train loss: 0.12386
# Epoch: 9/40 Iteration: 2200 | Train loss: 0.25376
# Epoch: 9/40 Iteration: 2220 | Train loss: 0.25540
# Epoch: 9/40 Iteration: 2240 | Train loss: 0.04297
# Epoch: 10/40 Iteration: 2260 | Train loss: 0.00893
# Epoch: 10/40 Iteration: 2280 | Train loss: 0.01657
# Epoch: 10/40 Iteration: 2300 | Train loss: 0.00820
# Epoch: 10/40 Iteration: 2320 | Train loss: 0.01188
# Epoch: 10/40 Iteration: 2340 | Train loss: 0.02204
# Epoch: 10/40 Iteration: 2360 | Train loss: 0.05398
# Epoch: 10/40 Iteration: 2380 | Train loss: 0.08081
# Epoch: 10/40 Iteration: 2400 | Train loss: 0.01476
# Epoch: 10/40 Iteration: 2420 | Train loss: 0.06216
# Epoch: 10/40 Iteration: 2440 | Train loss: 0.07189
# Epoch: 10/40 Iteration: 2460 | Train loss: 0.03562
# Epoch: 10/40 Iteration: 2480 | Train loss: 0.06288
# Epoch: 10/40 Iteration: 2500 | Train loss: 0.19078
# Epoch: 11/40 Iteration: 2520 | Train loss: 0.05247
# Epoch: 11/40 Iteration: 2540 | Train loss: 0.00970
# Epoch: 11/40 Iteration: 2560 | Train loss: 0.08479
# Epoch: 11/40 Iteration: 2580 | Train loss: 0.04933
# Epoch: 11/40 Iteration: 2600 | Train loss: 0.01559
# Epoch: 11/40 Iteration: 2620 | Train loss: 0.05763
# Epoch: 11/40 Iteration: 2640 | Train loss: 0.03804
# Epoch: 11/40 Iteration: 2660 | Train loss: 0.00247
# Epoch: 11/40 Iteration: 2680 | Train loss: 0.00565
# Epoch: 11/40 Iteration: 2700 | Train loss: 0.03183
# Epoch: 11/40 Iteration: 2720 | Train loss: 0.00204
# Epoch: 11/40 Iteration: 2740 | Train loss: 0.01100
# Epoch: 12/40 Iteration: 2760 | Train loss: 0.00802
# Epoch: 12/40 Iteration: 2780 | Train loss: 0.00838
# Epoch: 12/40 Iteration: 2800 | Train loss: 0.00302
# Epoch: 12/40 Iteration: 2820 | Train loss: 0.03679
# Epoch: 12/40 Iteration: 2840 | Train loss: 0.01248
# Epoch: 12/40 Iteration: 2860 | Train loss: 0.02390
# Epoch: 12/40 Iteration: 2880 | Train loss: 0.06466
# Epoch: 12/40 Iteration: 2900 | Train loss: 0.03859
# Epoch: 12/40 Iteration: 2920 | Train loss: 0.12015
# Epoch: 12/40 Iteration: 2940 | Train loss: 0.00294
# Epoch: 12/40 Iteration: 2960 | Train loss: 0.00390
# Epoch: 12/40 Iteration: 2980 | Train loss: 0.01251
# Epoch: 12/40 Iteration: 3000 | Train loss: 0.01331
# Epoch: 13/40 Iteration: 3020 | Train loss: 0.03244
# Epoch: 13/40 Iteration: 3040 | Train loss: 0.00486
# Epoch: 13/40 Iteration: 3060 | Train loss: 0.11741
# Epoch: 13/40 Iteration: 3080 | Train loss: 0.02674
# Epoch: 13/40 Iteration: 3100 | Train loss: 0.02227
# Epoch: 13/40 Iteration: 3120 | Train loss: 0.03736
# Epoch: 13/40 Iteration: 3140 | Train loss: 0.06544
# Epoch: 13/40 Iteration: 3160 | Train loss: 0.00759
# Epoch: 13/40 Iteration: 3180 | Train loss: 0.00228
# Epoch: 13/40 Iteration: 3200 | Train loss: 0.02289
# Epoch: 13/40 Iteration: 3220 | Train loss: 0.00308
# Epoch: 13/40 Iteration: 3240 | Train loss: 0.03686
# Epoch: 14/40 Iteration: 3260 | Train loss: 0.00118
# Epoch: 14/40 Iteration: 3280 | Train loss: 0.00330
# Epoch: 14/40 Iteration: 3300 | Train loss: 0.00135
# Epoch: 14/40 Iteration: 3320 | Train loss: 0.00058
# Epoch: 14/40 Iteration: 3340 | Train loss: 0.04257
# Epoch: 14/40 Iteration: 3360 | Train loss: 0.00193
# Epoch: 14/40 Iteration: 3380 | Train loss: 0.05744
# Epoch: 14/40 Iteration: 3400 | Train loss: 0.00159
# Epoch: 14/40 Iteration: 3420 | Train loss: 0.06358
# Epoch: 14/40 Iteration: 3440 | Train loss: 0.03425
# Epoch: 14/40 Iteration: 3460 | Train loss: 0.05493
# Epoch: 14/40 Iteration: 3480 | Train loss: 0.01376
# Epoch: 14/40 Iteration: 3500 | Train loss: 0.00796
# Epoch: 15/40 Iteration: 3520 | Train loss: 0.02557
# Epoch: 15/40 Iteration: 3540 | Train loss: 0.00461
# Epoch: 15/40 Iteration: 3560 | Train loss: 0.10629
# Epoch: 15/40 Iteration: 3580 | Train loss: 0.04537
# Epoch: 15/40 Iteration: 3600 | Train loss: 0.02648
# Epoch: 15/40 Iteration: 3620 | Train loss: 0.04706
# Epoch: 15/40 Iteration: 3640 | Train loss: 0.00507
# Epoch: 15/40 Iteration: 3660 | Train loss: 0.01458
# Epoch: 15/40 Iteration: 3680 | Train loss: 0.00805
# Epoch: 15/40 Iteration: 3700 | Train loss: 0.00570
# Epoch: 15/40 Iteration: 3720 | Train loss: 0.00684
# Epoch: 15/40 Iteration: 3740 | Train loss: 0.04159
# Epoch: 16/40 Iteration: 3760 | Train loss: 0.00799
# Epoch: 16/40 Iteration: 3780 | Train loss: 0.00125
# Epoch: 16/40 Iteration: 3800 | Train loss: 0.00272
# Epoch: 16/40 Iteration: 3820 | Train loss: 0.00206
# Epoch: 16/40 Iteration: 3840 | Train loss: 0.00489
# Epoch: 16/40 Iteration: 3860 | Train loss: 0.00103
# Epoch: 16/40 Iteration: 3880 | Train loss: 0.02232
# Epoch: 16/40 Iteration: 3900 | Train loss: 0.01105
# Epoch: 16/40 Iteration: 3920 | Train loss: 0.03432
# Epoch: 16/40 Iteration: 3940 | Train loss: 0.00092
# Epoch: 16/40 Iteration: 3960 | Train loss: 0.00048
# Epoch: 16/40 Iteration: 3980 | Train loss: 0.00205
# Epoch: 16/40 Iteration: 4000 | Train loss: 0.00468
# Epoch: 17/40 Iteration: 4020 | Train loss: 0.00410
# Epoch: 17/40 Iteration: 4040 | Train loss: 0.00048
# Epoch: 17/40 Iteration: 4060 | Train loss: 0.00295
# Epoch: 17/40 Iteration: 4080 | Train loss: 0.00998
# Epoch: 17/40 Iteration: 4100 | Train loss: 0.00168
# Epoch: 17/40 Iteration: 4120 | Train loss: 0.00122
# Epoch: 17/40 Iteration: 4140 | Train loss: 0.00091
# Epoch: 17/40 Iteration: 4160 | Train loss: 0.00074
# Epoch: 17/40 Iteration: 4180 | Train loss: 0.00030
# Epoch: 17/40 Iteration: 4200 | Train loss: 0.00121
# Epoch: 17/40 Iteration: 4220 | Train loss: 0.00020
# Epoch: 17/40 Iteration: 4240 | Train loss: 0.00239
# Epoch: 18/40 Iteration: 4260 | Train loss: 0.00072
# Epoch: 18/40 Iteration: 4280 | Train loss: 0.00034
# Epoch: 18/40 Iteration: 4300 | Train loss: 0.00018
# Epoch: 18/40 Iteration: 4320 | Train loss: 0.00028
# Epoch: 18/40 Iteration: 4340 | Train loss: 0.00043
# Epoch: 18/40 Iteration: 4360 | Train loss: 0.00047
# Epoch: 18/40 Iteration: 4380 | Train loss: 0.00109
# Epoch: 18/40 Iteration: 4400 | Train loss: 0.00026
# Epoch: 18/40 Iteration: 4420 | Train loss: 0.00731
# Epoch: 18/40 Iteration: 4440 | Train loss: 0.00043
# Epoch: 18/40 Iteration: 4460 | Train loss: 0.00009
# Epoch: 18/40 Iteration: 4480 | Train loss: 0.00034
# Epoch: 18/40 Iteration: 4500 | Train loss: 0.00029
# Epoch: 19/40 Iteration: 4520 | Train loss: 0.00103
# Epoch: 19/40 Iteration: 4540 | Train loss: 0.00036
# Epoch: 19/40 Iteration: 4560 | Train loss: 0.00048
# Epoch: 19/40 Iteration: 4580 | Train loss: 0.00095
# Epoch: 19/40 Iteration: 4600 | Train loss: 0.00052
# Epoch: 19/40 Iteration: 4620 | Train loss: 0.00157
# Epoch: 19/40 Iteration: 4640 | Train loss: 0.00010
# Epoch: 19/40 Iteration: 4660 | Train loss: 0.00042
# Epoch: 19/40 Iteration: 4680 | Train loss: 0.00010
# Epoch: 19/40 Iteration: 4700 | Train loss: 0.00028
# Epoch: 19/40 Iteration: 4720 | Train loss: 0.00051
# Epoch: 19/40 Iteration: 4740 | Train loss: 0.00035
# Epoch: 20/40 Iteration: 4760 | Train loss: 0.00014
# Epoch: 20/40 Iteration: 4780 | Train loss: 0.00007
# Epoch: 20/40 Iteration: 4800 | Train loss: 0.00015
# Epoch: 20/40 Iteration: 4820 | Train loss: 0.00026
# Epoch: 20/40 Iteration: 4840 | Train loss: 0.00048
# Epoch: 20/40 Iteration: 4860 | Train loss: 0.00018
# Epoch: 20/40 Iteration: 4880 | Train loss: 0.00085
# Epoch: 20/40 Iteration: 4900 | Train loss: 0.00023
# Epoch: 20/40 Iteration: 4920 | Train loss: 0.00275
# Epoch: 20/40 Iteration: 4940 | Train loss: 0.00008
# Epoch: 20/40 Iteration: 4960 | Train loss: 0.00010
# Epoch: 20/40 Iteration: 4980 | Train loss: 0.00012
# Epoch: 20/40 Iteration: 5000 | Train loss: 0.00022
# Epoch: 21/40 Iteration: 5020 | Train loss: 0.00132
# Epoch: 21/40 Iteration: 5040 | Train loss: 0.00023
# Epoch: 21/40 Iteration: 5060 | Train loss: 0.00043
# Epoch: 21/40 Iteration: 5080 | Train loss: 0.00099
# Epoch: 21/40 Iteration: 5100 | Train loss: 0.00012
# Epoch: 21/40 Iteration: 5120 | Train loss: 0.00231
# Epoch: 21/40 Iteration: 5140 | Train loss: 0.00018
# Epoch: 21/40 Iteration: 5160 | Train loss: 0.00020
# Epoch: 21/40 Iteration: 5180 | Train loss: 0.00012
# Epoch: 21/40 Iteration: 5200 | Train loss: 0.00013
# Epoch: 21/40 Iteration: 5220 | Train loss: 0.00022
# Epoch: 21/40 Iteration: 5240 | Train loss: 0.00019
# Epoch: 22/40 Iteration: 5260 | Train loss: 0.00014
# Epoch: 22/40 Iteration: 5280 | Train loss: 0.00005
# Epoch: 22/40 Iteration: 5300 | Train loss: 0.00014
# Epoch: 22/40 Iteration: 5320 | Train loss: 0.00014
# Epoch: 22/40 Iteration: 5340 | Train loss: 0.00019
# Epoch: 22/40 Iteration: 5360 | Train loss: 0.00007
# Epoch: 22/40 Iteration: 5380 | Train loss: 0.00104
# Epoch: 22/40 Iteration: 5400 | Train loss: 0.00012
# Epoch: 22/40 Iteration: 5420 | Train loss: 0.00262
# Epoch: 22/40 Iteration: 5440 | Train loss: 0.00007
# Epoch: 22/40 Iteration: 5460 | Train loss: 0.00004
# Epoch: 22/40 Iteration: 5480 | Train loss: 0.00006
# Epoch: 22/40 Iteration: 5500 | Train loss: 0.00084
# Epoch: 23/40 Iteration: 5520 | Train loss: 0.00019
# Epoch: 23/40 Iteration: 5540 | Train loss: 0.00011
# Epoch: 23/40 Iteration: 5560 | Train loss: 0.00059
# Epoch: 23/40 Iteration: 5580 | Train loss: 0.00069
# Epoch: 23/40 Iteration: 5600 | Train loss: 0.00007
# Epoch: 23/40 Iteration: 5620 | Train loss: 0.00005
# Epoch: 23/40 Iteration: 5640 | Train loss: 0.00007
# Epoch: 23/40 Iteration: 5660 | Train loss: 0.00006
# Epoch: 23/40 Iteration: 5680 | Train loss: 0.00013
# Epoch: 23/40 Iteration: 5700 | Train loss: 0.00010
# Epoch: 23/40 Iteration: 5720 | Train loss: 0.00008
# Epoch: 23/40 Iteration: 5740 | Train loss: 0.00016
# Epoch: 24/40 Iteration: 5760 | Train loss: 0.00005
# Epoch: 24/40 Iteration: 5780 | Train loss: 0.00002
# Epoch: 24/40 Iteration: 5800 | Train loss: 0.00004
# Epoch: 24/40 Iteration: 5820 | Train loss: 0.00004
# Epoch: 24/40 Iteration: 5840 | Train loss: 0.00009
# Epoch: 24/40 Iteration: 5860 | Train loss: 0.00007
# Epoch: 24/40 Iteration: 5880 | Train loss: 0.00066
# Epoch: 24/40 Iteration: 5900 | Train loss: 0.00018
# Epoch: 24/40 Iteration: 5920 | Train loss: 0.00013
# Epoch: 24/40 Iteration: 5940 | Train loss: 0.00003
# Epoch: 24/40 Iteration: 5960 | Train loss: 0.00003
# Epoch: 24/40 Iteration: 5980 | Train loss: 0.00021
# Epoch: 24/40 Iteration: 6000 | Train loss: 0.00006
# Epoch: 25/40 Iteration: 6020 | Train loss: 0.00015
# Epoch: 25/40 Iteration: 6040 | Train loss: 0.00036
# Epoch: 25/40 Iteration: 6060 | Train loss: 0.00019
# Epoch: 25/40 Iteration: 6080 | Train loss: 0.00007
# Epoch: 25/40 Iteration: 6100 | Train loss: 0.00010
# Epoch: 25/40 Iteration: 6120 | Train loss: 0.00001
# Epoch: 25/40 Iteration: 6140 | Train loss: 0.00002
# Epoch: 25/40 Iteration: 6160 | Train loss: 0.00006
# Epoch: 25/40 Iteration: 6180 | Train loss: 0.00002
# Epoch: 25/40 Iteration: 6200 | Train loss: 0.00004
# Epoch: 25/40 Iteration: 6220 | Train loss: 0.00002
# Epoch: 25/40 Iteration: 6240 | Train loss: 0.00078
# Epoch: 26/40 Iteration: 6260 | Train loss: 0.00003
# Epoch: 26/40 Iteration: 6280 | Train loss: 0.00006
# Epoch: 26/40 Iteration: 6300 | Train loss: 0.00010
# Epoch: 26/40 Iteration: 6320 | Train loss: 0.00002
# Epoch: 26/40 Iteration: 6340 | Train loss: 0.00017
# Epoch: 26/40 Iteration: 6360 | Train loss: 0.00004
# Epoch: 26/40 Iteration: 6380 | Train loss: 0.00149
# Epoch: 26/40 Iteration: 6400 | Train loss: 0.00006
# Epoch: 26/40 Iteration: 6420 | Train loss: 0.00030
# Epoch: 26/40 Iteration: 6440 | Train loss: 0.00003
# Epoch: 26/40 Iteration: 6460 | Train loss: 0.00002
# Epoch: 26/40 Iteration: 6480 | Train loss: 0.00015
# Epoch: 26/40 Iteration: 6500 | Train loss: 0.00004
# Epoch: 27/40 Iteration: 6520 | Train loss: 0.00005
# Epoch: 27/40 Iteration: 6540 | Train loss: 0.00002
# Epoch: 27/40 Iteration: 6560 | Train loss: 0.00008
# Epoch: 27/40 Iteration: 6580 | Train loss: 0.00005
# Epoch: 27/40 Iteration: 6600 | Train loss: 0.00001
# Epoch: 27/40 Iteration: 6620 | Train loss: 0.00046
# Epoch: 27/40 Iteration: 6640 | Train loss: 0.00001
# Epoch: 27/40 Iteration: 6660 | Train loss: 0.00008
# Epoch: 27/40 Iteration: 6680 | Train loss: 0.00003
# Epoch: 27/40 Iteration: 6700 | Train loss: 0.00002
# Epoch: 27/40 Iteration: 6720 | Train loss: 0.00001
# Epoch: 27/40 Iteration: 6740 | Train loss: 0.00003
# Epoch: 28/40 Iteration: 6760 | Train loss: 0.00002
# Epoch: 28/40 Iteration: 6780 | Train loss: 0.00009
# Epoch: 28/40 Iteration: 6800 | Train loss: 0.00001
# Epoch: 28/40 Iteration: 6820 | Train loss: 0.00001
# Epoch: 28/40 Iteration: 6840 | Train loss: 0.00010
# Epoch: 28/40 Iteration: 6860 | Train loss: 0.00003
# Epoch: 28/40 Iteration: 6880 | Train loss: 0.00009
# Epoch: 28/40 Iteration: 6900 | Train loss: 0.00001
# Epoch: 28/40 Iteration: 6920 | Train loss: 0.00002
# Epoch: 28/40 Iteration: 6940 | Train loss: 0.00001
# Epoch: 28/40 Iteration: 6960 | Train loss: 0.00001
# Epoch: 28/40 Iteration: 6980 | Train loss: 0.00002
# Epoch: 28/40 Iteration: 7000 | Train loss: 0.00001
# Epoch: 29/40 Iteration: 7020 | Train loss: 0.00002
# Epoch: 29/40 Iteration: 7040 | Train loss: 0.00002
# Epoch: 29/40 Iteration: 7060 | Train loss: 0.00004
# Epoch: 29/40 Iteration: 7080 | Train loss: 0.00003
# Epoch: 29/40 Iteration: 7100 | Train loss: 0.00003
# Epoch: 29/40 Iteration: 7120 | Train loss: 0.00000
# Epoch: 29/40 Iteration: 7140 | Train loss: 0.00000
# Epoch: 29/40 Iteration: 7160 | Train loss: 0.00001
# Epoch: 29/40 Iteration: 7180 | Train loss: 0.00001
# Epoch: 29/40 Iteration: 7200 | Train loss: 0.00002
# Epoch: 29/40 Iteration: 7220 | Train loss: 0.00001
# Epoch: 29/40 Iteration: 7240 | Train loss: 0.00005
# Epoch: 30/40 Iteration: 7260 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7280 | Train loss: 0.00001
# Epoch: 30/40 Iteration: 7300 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7320 | Train loss: 0.00001
# Epoch: 30/40 Iteration: 7340 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7360 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7380 | Train loss: 0.00012
# Epoch: 30/40 Iteration: 7400 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7420 | Train loss: 0.00004
# Epoch: 30/40 Iteration: 7440 | Train loss: 0.00001
# Epoch: 30/40 Iteration: 7460 | Train loss: 0.00001
# Epoch: 30/40 Iteration: 7480 | Train loss: 0.00002
# Epoch: 30/40 Iteration: 7500 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7520 | Train loss: 0.00004
# Epoch: 31/40 Iteration: 7540 | Train loss: 0.00000
# Epoch: 31/40 Iteration: 7560 | Train loss: 0.00003
# Epoch: 31/40 Iteration: 7580 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7600 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7620 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7640 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7660 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7680 | Train loss: 0.00000
# Epoch: 31/40 Iteration: 7700 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7720 | Train loss: 0.00001
# Epoch: 31/40 Iteration: 7740 | Train loss: 0.00003
# Epoch: 32/40 Iteration: 7760 | Train loss: 0.00004
# Epoch: 32/40 Iteration: 7780 | Train loss: 0.00000
# Epoch: 32/40 Iteration: 7800 | Train loss: 0.00000
# Epoch: 32/40 Iteration: 7820 | Train loss: 0.00000
# Epoch: 32/40 Iteration: 7840 | Train loss: 0.00008
# Epoch: 32/40 Iteration: 7860 | Train loss: 0.00002
# Epoch: 32/40 Iteration: 7880 | Train loss: 0.00003
# Epoch: 32/40 Iteration: 7900 | Train loss: 0.00002
# Epoch: 32/40 Iteration: 7920 | Train loss: 0.00008
# Epoch: 32/40 Iteration: 7940 | Train loss: 0.00001
# Epoch: 32/40 Iteration: 7960 | Train loss: 0.00002
# Epoch: 32/40 Iteration: 7980 | Train loss: 0.00001
# Epoch: 32/40 Iteration: 8000 | Train loss: 0.00001
# Epoch: 33/40 Iteration: 8020 | Train loss: 0.00002
# Epoch: 33/40 Iteration: 8040 | Train loss: 0.00000
# Epoch: 33/40 Iteration: 8060 | Train loss: 0.00002
# Epoch: 33/40 Iteration: 8080 | Train loss: 0.00002
# Epoch: 33/40 Iteration: 8100 | Train loss: 0.00002
# Epoch: 33/40 Iteration: 8120 | Train loss: 0.00001
# Epoch: 33/40 Iteration: 8140 | Train loss: 0.00000
# Epoch: 33/40 Iteration: 8160 | Train loss: 0.00001
# Epoch: 33/40 Iteration: 8180 | Train loss: 0.00000
# Epoch: 33/40 Iteration: 8200 | Train loss: 0.00001
# Epoch: 33/40 Iteration: 8220 | Train loss: 0.00000
# Epoch: 33/40 Iteration: 8240 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8260 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8280 | Train loss: 0.00000
# Epoch: 34/40 Iteration: 8300 | Train loss: 0.00000
# Epoch: 34/40 Iteration: 8320 | Train loss: 0.00000
# Epoch: 34/40 Iteration: 8340 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8360 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8380 | Train loss: 0.00002
# Epoch: 34/40 Iteration: 8400 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8420 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8440 | Train loss: 0.00000
# Epoch: 34/40 Iteration: 8460 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8480 | Train loss: 0.00001
# Epoch: 34/40 Iteration: 8500 | Train loss: 0.00001
# Epoch: 35/40 Iteration: 8520 | Train loss: 0.00001
# Epoch: 35/40 Iteration: 8540 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8560 | Train loss: 0.00002
# Epoch: 35/40 Iteration: 8580 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8600 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8620 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8640 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8660 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8680 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8700 | Train loss: 0.00001
# Epoch: 35/40 Iteration: 8720 | Train loss: 0.00000
# Epoch: 35/40 Iteration: 8740 | Train loss: 0.00001
# Epoch: 36/40 Iteration: 8760 | Train loss: 0.00001
# Epoch: 36/40 Iteration: 8780 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8800 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8820 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8840 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8860 | Train loss: 0.00001
# Epoch: 36/40 Iteration: 8880 | Train loss: 0.00002
# Epoch: 36/40 Iteration: 8900 | Train loss: 0.00001
# Epoch: 36/40 Iteration: 8920 | Train loss: 0.00004
# Epoch: 36/40 Iteration: 8940 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8960 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 8980 | Train loss: 0.00000
# Epoch: 36/40 Iteration: 9000 | Train loss: 0.00001
# Epoch: 37/40 Iteration: 9020 | Train loss: 0.00001
# Epoch: 37/40 Iteration: 9040 | Train loss: 0.00000
# Epoch: 37/40 Iteration: 9060 | Train loss: 0.00001
# Epoch: 37/40 Iteration: 9080 | Train loss: 0.00001
# Epoch: 37/40 Iteration: 9100 | Train loss: 0.00000
# Epoch: 37/40 Iteration: 9120 | Train loss: 0.00002
# Epoch: 37/40 Iteration: 9140 | Train loss: 0.00000
# Epoch: 37/40 Iteration: 9160 | Train loss: 0.00000
# Epoch: 37/40 Iteration: 9180 | Train loss: 0.04285
# Epoch: 37/40 Iteration: 9200 | Train loss: 0.08062
# Epoch: 37/40 Iteration: 9220 | Train loss: 0.02638
# Epoch: 37/40 Iteration: 9240 | Train loss: 0.08213
# Epoch: 38/40 Iteration: 9260 | Train loss: 0.05855
# Epoch: 38/40 Iteration: 9280 | Train loss: 0.05380
# Epoch: 38/40 Iteration: 9300 | Train loss: 0.03668
# Epoch: 38/40 Iteration: 9320 | Train loss: 0.02145
# Epoch: 38/40 Iteration: 9340 | Train loss: 0.01507
# Epoch: 38/40 Iteration: 9360 | Train loss: 0.07126
# Epoch: 38/40 Iteration: 9380 | Train loss: 0.01899
# Epoch: 38/40 Iteration: 9400 | Train loss: 0.08591
# Epoch: 38/40 Iteration: 9420 | Train loss: 0.02144
# Epoch: 38/40 Iteration: 9440 | Train loss: 0.03379
# Epoch: 38/40 Iteration: 9460 | Train loss: 0.00279
# Epoch: 38/40 Iteration: 9480 | Train loss: 0.00510
# Epoch: 38/40 Iteration: 9500 | Train loss: 0.00304
# Epoch: 39/40 Iteration: 9520 | Train loss: 0.00645
# Epoch: 39/40 Iteration: 9540 | Train loss: 0.03808
# Epoch: 39/40 Iteration: 9560 | Train loss: 0.04569
# Epoch: 39/40 Iteration: 9580 | Train loss: 0.01412
# Epoch: 39/40 Iteration: 9600 | Train loss: 0.00192
# Epoch: 39/40 Iteration: 9620 | Train loss: 0.00849
# Epoch: 39/40 Iteration: 9640 | Train loss: 0.00314
# Epoch: 39/40 Iteration: 9660 | Train loss: 0.00853
# Epoch: 39/40 Iteration: 9680 | Train loss: 0.00720
# Epoch: 39/40 Iteration: 9700 | Train loss: 0.00404
# Epoch: 39/40 Iteration: 9720 | Train loss: 0.00084
# Epoch: 39/40 Iteration: 9740 | Train loss: 0.00182
# Epoch: 40/40 Iteration: 9760 | Train loss: 0.00098
# Epoch: 40/40 Iteration: 9780 | Train loss: 0.00105
# Epoch: 40/40 Iteration: 9800 | Train loss: 0.00419
# Epoch: 40/40 Iteration: 9820 | Train loss: 0.00281
# Epoch: 40/40 Iteration: 9840 | Train loss: 0.00177
# Epoch: 40/40 Iteration: 9860 | Train loss: 0.00334
# Epoch: 40/40 Iteration: 9880 | Train loss: 0.01384
# Epoch: 40/40 Iteration: 9900 | Train loss: 0.00191
# Epoch: 40/40 Iteration: 9920 | Train loss: 0.00464
# Epoch: 40/40 Iteration: 9940 | Train loss: 0.00070
# Epoch: 40/40 Iteration: 9960 | Train loss: 0.00126
# Epoch: 40/40 Iteration: 9980 | Train loss: 0.00028
# Epoch: 40/40 Iteration: 10000 | Train loss: 0.00082

# %% [markdown]
# The trained model is saved using TensorFlow's checkpointing system, which we discussed in Chapter 14.  Now we can use the trained model for predicting the class labels on the test set, as follows:

# %%
preds = rnn.predict(X_test)
y_true = y_test[:len(preds)]
print("Test accuracy:  {:.3f}.".format(np.sum(preds == y_true) / len(y_true)))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/sentiment-39.ckpt
# Test accuracy:  0.853.

# %% [markdown]
# The result will show an accuracy of 85 percent.  Given the small size of this dataset, this is comparable to the test prediction accuracy obtained in Chapter 8.
#
# We can optimise this further by changing the hyperparameters of the model, such as `lstm_size`, `seq_len`, and `embed_size`, to achieve better generalisation performance.  However, for hyperparameter tuning, it is recommended that we create a separate validation set and that we don't repeatedly use the test set for evaluation to avoid introducing bias through test data leakage, which we discuess in Chapter 6.
#
# Also, if you're interested in the prediction probabilities on the test set rather than the class labels, then you can set `return_proba=True` as follows:

# %%
proba = rnn.predict(X_test, return_proba=True)
print(proba)
# Out:
# INFO:tensorflow:Restoring parameters from ./model/sentiment-39.ckpt
# [5.57116550e-07 9.99999046e-01 1.85828488e-02 ... 2.16272201e-06
#  1.14251845e-04 9.95571196e-01]

# %% [markdown]
# So this was our first RNN model for sentiment analysis.  We'll now go further and create an RNN for character-bycharacter language modeling in TensorFlow, as another popular application of sequence modeling.

# %% [markdown]
# ## Project two---Implementing an RNN for chatacter-level language modeling in TensorFlow.
#
# Language modeling is a fascinating application that enables machines to perform human-language-related tasks, such as generating English sentences.  One of the most interesting efforts in this area is the work done by Sutskever, Martens, and Hinton (_Generating Text with Recurrent Neural Networks, Ilya Sutskever, James Martens, and Geoffrey E. Hinton, Proceedings of the 28th International Conference on Machine Learning (ICML-11), 2011_ https://pdfs.semanticscholar.org/93c2/0e38c85b69fc2d2eb314b3c1217913f7db11.pdf).
#
# In the model that we'll build now, the input is a text document, and our goal is to develop a model that can generate new text siilar to the input document.  Examples of such an input can be a book or a computer program in a specific programming language.
#
# In the character-level language modeling, the input is broken down into a sequence of characters that are fed into our network one characer at a time.  The network will process each new character in conjunction with the memory of the previously seen characters to predict the next character.  The following figure shows an example of character-level language modeling.
#
# <img src="images/16_11.png" style="width:500px">
#
# We can break this implementation down into three separate steps---preparing the data, building the RNN model, and performing next-character prediction and sampling to generate new text.
#
# If you recall from the previous sections of this chapter, we mentioned the exploding gradient problem.  In this application, we'll also get a chance to play with a gradient clipping technique to avoid this exploding gradient problem.

# %% [markdown]
# ## Preparing the Data
#
# In this section, we prepare the data fro character-level language modeling.
#
# To get the input data, visit the Project Gutenberg website at https://www.gutenberg.org/, which provides thousands of free e-books.  For our example, we can get the book _The Tragedie of Hamlet_ by William Shakespeare in plain text format from http://www.gutenberg.org/cache/epub/2265/pg2265.txt.
#
# Note that this link will directly take you to the download page.  If you are using macOS or a Linux operating system, you can download the file with the following command in the Terminal:
# `curl https://www.gutenberg.org/cache/epub/2265/pg2265.txt > pg2265.txt`
#
# If this resource becomes unavailable in the future, a copy of this text is also included in this chapter's code directory in the book's code repository at https://github.com/rasbt/python-machine-learning-book-2nd-edition.
#
# Once we have some data, we can read it into a Python session as plain text.  In the following code, the Python variable `chars` represents the set of unique characters observed in this text.  We then create a dictionary that maps each character to an integer, `char2int`, and a dictionary that performs reverse mapping, for instance, mapping integers to those unique characters---`int2char`.  Using the `char2int` dictionary, we convert the text into a NumPy array of integers.  The following figure shows an example of converting characters into integers and the reverse for the words `"Hello"` and `"world"`:
#
# <img src="images/16_12.png" style="width:500px">
#
# The code below reads the text from the downloaded link, removes the beginning portion of the text that contains some legal description of the Gutenberg project, and then constructs the dictionaries based on the text:

# %%
import numpy as np

# Reading and processing the text
with open("1257.txt", "r", encoding="utf-8") as f:
    text = f.read()
# text = text[15858:]
chars = set(text)

char2int = {ch: i for i, ch in enumerate(chars)}
int2char = dict(enumerate(chars))
text_ints = np.array([char2int[ch] for ch in text], dtype=np.int32)

# %% [markdown]
# Now, we should reshape the data into batches of sequences, the most important step in preparing the data.  As we know, the goal is to predict the next character, based on the sequene of characters that we have observed so far.  Therefore, we shift the input $(\mathbf{x})$ and output $(\mathbf{y})$ of the neural network by one character.  The following figure shows the preprocessing steps, starting from a text corpus to generating data arrays for $\mathbf{x}$ and $\mathbf{y}$:
#
# <img src="images/16_13.png" style="width:500px">
#
# As you can see in this figure, the training arrays $\mathbf{x}$ and $\mathbf{y}$ have the same shapes or dimensions, where the number of rows is equal to the _batch size_ and the number of columns is equal to _number of batches$\times$number of steps_.
#
# Given the input array `data` that contains the integers that correspond to the characters in the text corpus, the following function will generate `x` and `y` with the same structure shown in the previous figure.

# %%
def reshape_data(sequence, batch_size, num_steps):
    tot_batch_length = batch_size * num_steps
    num_batches = int(len(sequence) / tot_batch_length)
    if num_batches*tot_batch_length + 1 > len(sequence):
        num_batches = num_batches - 1
    
    # Truncatethe sequence at the end to get rid of the remaining characters that do not make a full batch
    x = sequence[0: num_batches*tot_batch_length]
    y = sequence[1: num_batches*tot_batch_length + 1]
    
    # Split x and y into a list batches of sequences:
    x_batch_splits = np.split(x, batch_size)
    y_batch_splits = np.split(y, batch_size)
    
    # Stack the batches together batch_size x tot_batch_length
    x = np.stack(x_batch_splits)
    y = np.stack(y_batch_splits)
    
    return x, y

# %% [markdown]
# The next step is to split the arrays $\mathbf{x}$ and $\mathbf{y}$ into mini-batches, where each row is a sequence with length equal to the _number of steps_.  The process of splitting the data array $\mathbf{x}$ is shown in the following figure:
#
# <img src="images/16_14.png" style="width:500px">
#
# In the following code, we define a function named `create_batch_generator` that splits the data arrays $\mathbf{x}$ and $\mathbf{y}$, as shown in the previous figure, and outputs a batch generator.  Later, we will use this generator to iterate through the mini-batches during the training of our network:

# %%
def create_batch_generator(data_x, data_y, num_steps):
    batch_size, tot_batch_length = data_x.shape
    num_batches = int(tot_batch_length / num_steps)
    for b in range(num_batches):
        yield (data_x[:, b*num_steps:(b+1)*num_steps],
               data_y[:, b*num_steps:(b+1)*num_steps])

# %% [markdown]
# At this point, we've now completed the data preprocessing steps, and we have the data in the proper format.  In the next section, we'll implement the RNN model for character-level language modeling.

# %% [markdown]
# ## Building a character-level RNN model
#
# To build a character-level neural network, we'll implement a class called `CharRNN` that constructs the graph of the RNN in order to predict the next character, after observing a given sequence of characters.  From the classification perspective, the number of classes is the total number of unique characters that exists in the text corpus.  The `CharRNN` class has four method, as follows:
# - A constructor that sets up the learning parameters, creates a computation graph, and calls the `build` method to construct the graph based on the sampling mode versus the training mode.
# - A `build` method that defines the placeholders for feeding the data, constructs the RNN using LSTM cells, and defines the output of the network, the cost function, and the optimizer.
# - A `train` method to iterate through the mini-batches, and train the network for the specified number of epochs.
# - A `sample` method to start from a given string, calculate the probabilities for the next character, and choose a character randomly according to these probabilities.  This process will be repeated, and the sampled characters will be concatenated together to form a string.  Once the size of this string reaches the specified length, it will return the string.
#
# We'll break these four methods into separate code sections and explain each one.  Note that implementing the RNN part of this model is very similar to the implementation in the _Project one---Performing sentiment analysis of IMDb movie reviews using multilayer RNNs_ section.  So, we'll skip the description of building the RNN components here.

# %% [markdown]
# ## Some code that needs to be defined now; this is explained at the end.
#
# In this `get_top_char` function, the probabilities are first sorted, then the `top_n` probabilities are passed to the `numpy.random.choice` function to randomly select one out of these top probabilities.  The implementation of the `get_top_char` function is as follows.
#
# Note, of course, that this function should be defined _before_ the definition of the `CharRNN` class.

# %%
def get_top_char(probas, char_size, top_n=5):
    p = np.squeeze(probas)
    p[np.argsort(p)[:-top_n]] = 0.0
    p = p / np.sum(p)
    ch_id = np.random.choice(char_size, 1, p=p)[0]
    return ch_id

# %% [markdown]
# ## The constructor
#
# In contrast to our previous implementation for sentiment analysis, where the same computation graph was used for both training and prediction modes, this time our computation graph is going to be different for the training versus sampling mode.
#
# Therefore, we need to add a new Boolean type argument to the constructor, to determine whether we're building the model for the training mode or the sampling mode.  The following code shows the implementation of the constructor enclosed in the class definition, amongst others...
#
# As we planned earlier, the Boolean `sampling` argument is used to determine whether the instance of `CharRNN` is for building the graph in the training mode (`sampling=False`), or the sampling mode (`sampling=True`).
#
# In addition to the `sampling` argument, we've introduced a new argument called `grad_clip`, which is used for clipping the gradients to avoid the exploding gradient problem that we mentioned earlier.
#
# Then, similar to the previous implementation, the constructor creates a computation graph, sets the graph-level random seed, for consistent output, and build the graph by calling the `build` method.
#
# ## The build method
#
# The next method of the `CharRNN` class is `build`, which is very similar to the `build` method in the _Project one---performing sentiment analysis of IMDb movie reviews using multilayer RNNs_ section, except for some minor differences.  The `build` method first defines two local variables, `batch_size`, and `num_steps`, based on the mode, as follows:
#
# $$
# \mathrm{in\ sampling\ mode}:
# \begin{cases}
#     \mathrm{batch\_size} = 1 \\
#     \mathrm{num\_steps} = 1
# \end{cases}
# $$
#
# $$
# \mathrm{in\ training\ mode}:
# \begin{cases}
#     \mathrm{batch\_size} = \mathrm{self.batch\_size} \\
#     \mathrm{num\_steps} = \mathrm{self.num\_steps}
# \end{cases}
# $$
#
# Recall that in the sentiment analysis implementation, we used an embedding layer to create a salient representation for the unique words in the dataset.  In contrast, here we are using the one-hot encoding scheme for both $x$ and $y$ with `depth=num_classes`, where `num_classes` is in fact the total number of characters in the text corpus.
#
# Building a multilayer RNN component of the model is exactly the same as in our sentiment analysis implementation, using the `tf.nn.dynamic_rnn` function.  However, `outputs` from the `tf.nn.dynamic_nn` function is a three-dimensional tensor with this shape---`batch_size, num_steps, lstm_size`.  Next, this tensor will be reshaped into a two-dimensional tensor with the `batch_size*num_steps, lstm_size` shape, which is passed to the `tf.layers.dense` function to make a fully connected layer and obtain `logits` (net inputs).  Finally, the probabilities for the next batch of characters are obtained and the cost function is defined.  In addition, here, we apply gradient clipping using the `tf.clip_by_global_norm` function to avoid the exploding gradient problem.
#
# ## The train method
#
# The next method of the `CharRNN` class is the `train` method, which is very similar to the `train` method described in the `Project one---performing sentiment analysis of IMDb movie reviews using multilayer RNNs` section.
#
# ##  The sample method
#
# The final method in our `CharRNN` class is the `sample` method.  The behavior of this `sample` method is similar to that of the `predict` method we implemented in the `Project one---performing sentiment analysis of IMDb movie review using multilayer RNNs` section.  However, the difference here is that we calculate the probabilities for the next character from an observed sequence---`observed_seq`.  Then, these probabilities are passes to a function named `get_top_char`, which randomly selects one character acording to the obtained probabilities.
#
# Initially, the observed sequence starts from `starter_seq`, which is provided as an argument.  When new characters are sampled according to their predicted probabilities, they are appended to the observed sequence, and the new observed sequence is used for predicting the next character.
#
# So here, the `sample` method calls the `get_top_char` function to choose a character ID randomly (`ch_id`) according to the obtained probabilities.
#
# In this `get_top_char` function, the probabilities are first sorted, then the `top_n` probabilities are passed to the `numpy.random.choice` function to randomly select one out of these probabilities.

# %%
import tensorflow as tf
import os

class CharRNN(object):
    def __init__(self, num_classes, batch_size=64, num_steps=100, lstm_size=128,
                num_layers=1, learning_rate=0.001, keep_prob=0.5, grad_clip=5, sampling=False):
        self.num_classes = num_classes
        self.batch_size = batch_size
        self.num_steps = num_steps
        self.lstm_size = lstm_size
        self.num_layers = num_layers
        self.learning_rate = learning_rate
        self.keep_prob = keep_prob
        self.grad_clip = grad_clip
        
        self.g = tf.Graph()
        with self.g.as_default():
            tf.set_random_seed(123)
            
            self.build(sampling=sampling)
            
            self.saver = tf.train.Saver()
            
            self.init_op = tf.global_variables_initializer()
    
    def build(self, sampling):
        if sampling:
            batch_size, num_steps = 1, 1
        else:
            batch_size = self.batch_size
            num_steps = self.num_steps
        
        tf_x = tf.placeholder(tf.int32, shape=[batch_size, num_steps], name="tf_x")
        tf_y = tf.placeholder(tf.int32, shape=[batch_size, num_steps], name="tf_y")
        tf_keepprob = tf.placeholder(tf.float32, name="tf_keepprob")
        
        # One-hot encoding
        x_onehot = tf.one_hot(tf_x, depth=self.num_classes)
        y_onehot = tf.one_hot(tf_y, depth=self.num_classes)
        
        # Build the multi-layer RNN cells
        cells = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(
        self.lstm_size), output_keep_prob=tf_keepprob) for _ in range(self.num_layers)])
        
        # Define the initial state
        self.initial_state = cells.zero_state(batch_size, tf.float32)
        
        # Run each sequence step through the RNN
        lstm_outputs, self.final_state = tf.nn.dynamic_rnn(cells, x_onehot, initial_state=self.initial_state)
        
        print("  << lstm_outputs >>", lstm_outputs)
        
        seq_output_reshaped = tf.reshape(lstm_outputs, shape=[-1, self.lstm_size], name="seq_out_reshaped")
        
        logits = tf.layers.dense(inputs=seq_output_reshaped, units=self.num_classes,
                                 activation=None, name="logits")
        
        proba = tf.nn.softmax(logits, name="probabilities")
        
        y_reshaped = tf.reshape(y_onehot, shape=[-1, self.num_classes], name="y_reshaped")
        
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped),
                             name="cost")
        
        # Gradient clipping to avoid "exploding gradient"
        tvars = tf.trainable_variables()
        grads, _ = tf.clip_by_global_norm(tf.gradients(cost, tvars), self.grad_clip)
        optimizer = tf.train.AdamOptimizer(self.learning_rate)
        train_op = optimizer.apply_gradients(zip(grads, tvars), name="train_op")
    
    def train(self, train_x, train_y, num_epochs, ckpt_dir="./model/"):
        # Create the checkpoint directory if it does not exist
        if not os.path.exists(ckpt_dir):
            os.mkdir(ckpt_dir)
        
        with tf.Session(graph=self.g) as sess:
            sess.run(self.init_op)
            
            n_batches = int(train_x.shape[1]/self.num_steps)
            iterations = n_batches * num_epochs
            for epoch in range(num_epochs):
                
                # Train the network
                new_state = sess.run(self.initial_state)
                loss = 0
                # Mini-batch generator
                bgen = create_batch_generator(train_x, train_y, self.num_steps)
                for b, (batch_x, batch_y) in enumerate(bgen, 1):
                    iteration = epoch * n_batches + b
                    
                    feed = {"tf_x:0": batch_x, "tf_y:0": batch_y, "tf_keepprob:0": self.keep_prob,
                           self.initial_state: new_state}
                    batch_cost, _, new_state = sess.run(["cost:0", "train_op", self.final_state], feed_dict=feed)
                    if not iteration % 10:
                        print("Epoch {}/{} Iteration {} | Training Loss: {:.4f}.".format(epoch + 1, num_epochs,
                                                                                        iteration, batch_cost))
                
                # Save the trained model
                self.saver.save(sess, os.path.join(ckpt_dir, "language_modeling.ckpt"))
    
    def sample(self, output_length, ckpt_dir, starter_seq="Men "):
        observed_seq = [ch for ch in starter_seq]
        with tf.Session(graph=self.g) as sess:
            self.saver.restore(sess, tf.train.latest_checkpoint(ckpt_dir))
            
            # 1:  Run the model using the starter seq
            new_state = sess.run(self.initial_state)
            for ch in starter_seq:
                x = np.zeros((1, 1))
                x[0, 0] = char2int[ch]
                feed = {"tf_x:0": x, "tf_keepprob:0": 1.0, self.initial_state: new_state}
                proba, new_state = sess.run(["probabilities:0", self.final_state], feed_dict=feed)
            
            ch_id = get_top_char(proba, len(chars))
            observed_seq.append(int2char[ch_id])
            
            # 2:  Run the model using the updated ovserved_seq
            for i in range(output_length):
                x[0, 0] = ch_id
                feed = {"tf_x:0": x, "tf_keepprob:0": 1.0, self.initial_state: new_state}
                proba, new_state = sess.run(["probabilities:0", self.final_state], feed_dict=feed)
                
                ch_id = get_top_char(proba, len(chars))
                observed_seq.append(int2char[ch_id])
        return "".join(observed_seq)

# %% [markdown]
# ## Creating and Training the CharRNN Model.
#
# Now we are ready to create an instance of the `CharRNN` class to build the RNN model, and to train it with the following configurations:

# %%
batch_size = 64
num_steps = 100
train_x, train_y = reshape_data(text_ints, batch_size, num_steps)

rnn = CharRNN(num_classes=len(chars), batch_size=batch_size)
rnn.train(train_x, train_y, num_epochs=500, ckpt_dir="./model-500/")
# Out:
#   << lstm_outputs >> Tensor("rnn/transpose_1:0", shape=(64, 100, 128), dtype=float32)
# Epoch 1/500 Iteration 10 | Training Loss: 3.9287.
# Epoch 1/500 Iteration 20 | Training Loss: 3.4434.
# Epoch 1/500 Iteration 30 | Training Loss: 3.3455.
# Epoch 1/500 Iteration 40 | Training Loss: 3.2452.
# Epoch 1/500 Iteration 50 | Training Loss: 3.2319.
# Epoch 1/500 Iteration 60 | Training Loss: 3.2077.
# Epoch 1/500 Iteration 70 | Training Loss: 3.1810.
# Epoch 1/500 Iteration 80 | Training Loss: 3.1811.
# Epoch 1/500 Iteration 90 | Training Loss: 3.1635.
# Epoch 1/500 Iteration 100 | Training Loss: 3.1477.
# Epoch 1/500 Iteration 110 | Training Loss: 3.1109.
# Epoch 1/500 Iteration 120 | Training Loss: 3.1414.
# Epoch 1/500 Iteration 130 | Training Loss: 3.0823.
# Epoch 1/500 Iteration 140 | Training Loss: 3.0749.
# Epoch 1/500 Iteration 150 | Training Loss: 3.0285.
# Epoch 1/500 Iteration 160 | Training Loss: 3.0779.
# Epoch 1/500 Iteration 170 | Training Loss: 2.9796.
# Epoch 1/500 Iteration 180 | Training Loss: 2.9406.
# Epoch 1/500 Iteration 190 | Training Loss: 2.9023.
# Epoch 1/500 Iteration 200 | Training Loss: 2.8896.
# Epoch 2/500 Iteration 210 | Training Loss: 2.7989.
# Epoch 2/500 Iteration 220 | Training Loss: 2.7978.
# Epoch 2/500 Iteration 230 | Training Loss: 2.7520.
# Epoch 2/500 Iteration 240 | Training Loss: 2.7115.
# Epoch 2/500 Iteration 250 | Training Loss: 2.7269.
# Epoch 2/500 Iteration 260 | Training Loss: 2.6393.
# Epoch 2/500 Iteration 270 | Training Loss: 2.6265.
# Epoch 2/500 Iteration 280 | Training Loss: 2.6444.
# Epoch 2/500 Iteration 290 | Training Loss: 2.5590.
# Epoch 2/500 Iteration 300 | Training Loss: 2.5814.
# Epoch 2/500 Iteration 310 | Training Loss: 2.5349.
# Epoch 2/500 Iteration 320 | Training Loss: 2.5331.
# Epoch 2/500 Iteration 330 | Training Loss: 2.5237.
# Epoch 2/500 Iteration 340 | Training Loss: 2.4934.
# Epoch 2/500 Iteration 350 | Training Loss: 2.4906.
# Epoch 2/500 Iteration 360 | Training Loss: 2.5175.
# Epoch 2/500 Iteration 370 | Training Loss: 2.5090.
# Epoch 2/500 Iteration 380 | Training Loss: 2.4618.
# Epoch 2/500 Iteration 390 | Training Loss: 2.4421.
# Epoch 2/500 Iteration 400 | Training Loss: 2.4274.
# Epoch 3/500 Iteration 410 | Training Loss: 2.4157.
# Epoch 3/500 Iteration 420 | Training Loss: 2.4036.
# Epoch 3/500 Iteration 430 | Training Loss: 2.4082.
# Epoch 3/500 Iteration 440 | Training Loss: 2.3648.
# Epoch 3/500 Iteration 450 | Training Loss: 2.3777.
# Epoch 3/500 Iteration 460 | Training Loss: 2.3584.
# Epoch 3/500 Iteration 470 | Training Loss: 2.3657.
# Epoch 3/500 Iteration 480 | Training Loss: 2.3512.
# Epoch 3/500 Iteration 490 | Training Loss: 2.3297.
# Epoch 3/500 Iteration 500 | Training Loss: 2.3638.
# Epoch 3/500 Iteration 510 | Training Loss: 2.3264.
# Epoch 3/500 Iteration 520 | Training Loss: 2.3115.
# Epoch 3/500 Iteration 530 | Training Loss: 2.3335.
# Epoch 3/500 Iteration 540 | Training Loss: 2.2862.
# Epoch 3/500 Iteration 550 | Training Loss: 2.3348.
# Epoch 3/500 Iteration 560 | Training Loss: 2.3121.
# Epoch 3/500 Iteration 570 | Training Loss: 2.3555.
# Epoch 3/500 Iteration 580 | Training Loss: 2.3245.
# Epoch 3/500 Iteration 590 | Training Loss: 2.2899.
# Epoch 3/500 Iteration 600 | Training Loss: 2.2932.
# Epoch 3/500 Iteration 610 | Training Loss: 2.2933.
# Epoch 4/500 Iteration 620 | Training Loss: 2.2659.
# Epoch 4/500 Iteration 630 | Training Loss: 2.2359.
# Epoch 4/500 Iteration 640 | Training Loss: 2.2658.
# Epoch 4/500 Iteration 650 | Training Loss: 2.2615.
# Epoch 4/500 Iteration 660 | Training Loss: 2.2811.
# Epoch 4/500 Iteration 670 | Training Loss: 2.2478.
# Epoch 4/500 Iteration 680 | Training Loss: 2.2474.
# Epoch 4/500 Iteration 690 | Training Loss: 2.3344.
# Epoch 4/500 Iteration 700 | Training Loss: 2.2291.
# Epoch 4/500 Iteration 710 | Training Loss: 2.2430.
# Epoch 4/500 Iteration 720 | Training Loss: 2.2367.
# Epoch 4/500 Iteration 730 | Training Loss: 2.2187.
# Epoch 4/500 Iteration 740 | Training Loss: 2.2297.
# Epoch 4/500 Iteration 750 | Training Loss: 2.2563.
# Epoch 4/500 Iteration 760 | Training Loss: 2.1920.
# Epoch 4/500 Iteration 770 | Training Loss: 2.2441.
# Epoch 4/500 Iteration 780 | Training Loss: 2.2207.
# Epoch 4/500 Iteration 790 | Training Loss: 2.2171.
# Epoch 4/500 Iteration 800 | Training Loss: 2.1930.
# Epoch 4/500 Iteration 810 | Training Loss: 2.2071.
# Epoch 5/500 Iteration 820 | Training Loss: 2.2330.
# Epoch 5/500 Iteration 830 | Training Loss: 2.1742.
# Epoch 5/500 Iteration 840 | Training Loss: 2.2368.
# Epoch 5/500 Iteration 850 | Training Loss: 2.1998.
# Epoch 5/500 Iteration 860 | Training Loss: 2.1996.
# Epoch 5/500 Iteration 870 | Training Loss: 2.2048.
# Epoch 5/500 Iteration 880 | Training Loss: 2.1908.
# Epoch 5/500 Iteration 890 | Training Loss: 2.1820.
# Epoch 5/500 Iteration 900 | Training Loss: 2.1821.
# Epoch 5/500 Iteration 910 | Training Loss: 2.1831.
# Epoch 5/500 Iteration 920 | Training Loss: 2.1909.
# Epoch 5/500 Iteration 930 | Training Loss: 2.1744.
# Epoch 5/500 Iteration 940 | Training Loss: 2.1882.
# Epoch 5/500 Iteration 950 | Training Loss: 2.1897.
# Epoch 5/500 Iteration 960 | Training Loss: 2.1536.
# Epoch 5/500 Iteration 970 | Training Loss: 2.1807.
# Epoch 5/500 Iteration 980 | Training Loss: 2.1478.
# Epoch 5/500 Iteration 990 | Training Loss: 2.1817.
# Epoch 5/500 Iteration 1000 | Training Loss: 2.1634.
# Epoch 5/500 Iteration 1010 | Training Loss: 2.1235.
# Epoch 5/500 Iteration 1020 | Training Loss: 2.1769.
# Epoch 6/500 Iteration 1030 | Training Loss: 2.1543.
# Epoch 6/500 Iteration 1040 | Training Loss: 2.1397.
# Epoch 6/500 Iteration 1050 | Training Loss: 2.1642.
# Epoch 6/500 Iteration 1060 | Training Loss: 2.1151.
# Epoch 6/500 Iteration 1070 | Training Loss: 2.1279.
# Epoch 6/500 Iteration 1080 | Training Loss: 2.1469.
# Epoch 6/500 Iteration 1090 | Training Loss: 2.1447.
# Epoch 6/500 Iteration 1100 | Training Loss: 2.1056.
# Epoch 6/500 Iteration 1110 | Training Loss: 2.1157.
# Epoch 6/500 Iteration 1120 | Training Loss: 2.1280.
# Epoch 6/500 Iteration 1130 | Training Loss: 2.0938.
# Epoch 6/500 Iteration 1140 | Training Loss: 2.1046.
# Epoch 6/500 Iteration 1150 | Training Loss: 2.0937.
# Epoch 6/500 Iteration 1160 | Training Loss: 2.1043.
# Epoch 6/500 Iteration 1170 | Training Loss: 2.1071.
# Epoch 6/500 Iteration 1180 | Training Loss: 2.1456.
# Epoch 6/500 Iteration 1190 | Training Loss: 2.0876.
# Epoch 6/500 Iteration 1200 | Training Loss: 2.0945.
# Epoch 6/500 Iteration 1210 | Training Loss: 2.0971.
# Epoch 6/500 Iteration 1220 | Training Loss: 2.1306.
# Epoch 7/500 Iteration 1230 | Training Loss: 2.1025.
# Epoch 7/500 Iteration 1240 | Training Loss: 2.1006.
# Epoch 7/500 Iteration 1250 | Training Loss: 2.0855.
# Epoch 7/500 Iteration 1260 | Training Loss: 2.0701.
# Epoch 7/500 Iteration 1270 | Training Loss: 2.1171.
# Epoch 7/500 Iteration 1280 | Training Loss: 2.0470.
# Epoch 7/500 Iteration 1290 | Training Loss: 2.0803.
# Epoch 7/500 Iteration 1300 | Training Loss: 2.1341.
# Epoch 7/500 Iteration 1310 | Training Loss: 2.0438.
# Epoch 7/500 Iteration 1320 | Training Loss: 2.0876.
# Epoch 7/500 Iteration 1330 | Training Loss: 2.0751.
# Epoch 7/500 Iteration 1340 | Training Loss: 2.0634.
# Epoch 7/500 Iteration 1350 | Training Loss: 2.0760.
# Epoch 7/500 Iteration 1360 | Training Loss: 2.0818.
# Epoch 7/500 Iteration 1370 | Training Loss: 2.0585.
# Epoch 7/500 Iteration 1380 | Training Loss: 2.1043.
# Epoch 7/500 Iteration 1390 | Training Loss: 2.0374.
# Epoch 7/500 Iteration 1400 | Training Loss: 2.0807.
# Epoch 7/500 Iteration 1410 | Training Loss: 2.0791.
# Epoch 7/500 Iteration 1420 | Training Loss: 2.0833.
# Epoch 8/500 Iteration 1430 | Training Loss: 2.0490.
# Epoch 8/500 Iteration 1440 | Training Loss: 2.0473.
# Epoch 8/500 Iteration 1450 | Training Loss: 2.0867.
# Epoch 8/500 Iteration 1460 | Training Loss: 2.0128.
# Epoch 8/500 Iteration 1470 | Training Loss: 2.0305.
# Epoch 8/500 Iteration 1480 | Training Loss: 2.0319.
# Epoch 8/500 Iteration 1490 | Training Loss: 2.0303.
# Epoch 8/500 Iteration 1500 | Training Loss: 2.0164.
# Epoch 8/500 Iteration 1510 | Training Loss: 2.0305.
# Epoch 8/500 Iteration 1520 | Training Loss: 2.0303.
# Epoch 8/500 Iteration 1530 | Training Loss: 1.9798.
# Epoch 8/500 Iteration 1540 | Training Loss: 1.9896.
# Epoch 8/500 Iteration 1550 | Training Loss: 2.0131.
# Epoch 8/500 Iteration 1560 | Training Loss: 1.9684.
# Epoch 8/500 Iteration 1570 | Training Loss: 2.0126.
# Epoch 8/500 Iteration 1580 | Training Loss: 2.0058.
# Epoch 8/500 Iteration 1590 | Training Loss: 2.0520.
# Epoch 8/500 Iteration 1600 | Training Loss: 2.0289.
# Epoch 8/500 Iteration 1610 | Training Loss: 2.0188.
# Epoch 8/500 Iteration 1620 | Training Loss: 2.0283.
# Epoch 8/500 Iteration 1630 | Training Loss: 2.0323.
# Epoch 9/500 Iteration 1640 | Training Loss: 1.9939.
# Epoch 9/500 Iteration 1650 | Training Loss: 1.9372.
# Epoch 9/500 Iteration 1660 | Training Loss: 1.9978.
# Epoch 9/500 Iteration 1670 | Training Loss: 1.9892.
# Epoch 9/500 Iteration 1680 | Training Loss: 2.0404.
# Epoch 9/500 Iteration 1690 | Training Loss: 1.9815.
# Epoch 9/500 Iteration 1700 | Training Loss: 2.0077.
# Epoch 9/500 Iteration 1710 | Training Loss: 2.0754.
# Epoch 9/500 Iteration 1720 | Training Loss: 1.9865.
# Epoch 9/500 Iteration 1730 | Training Loss: 1.9849.
# Epoch 9/500 Iteration 1740 | Training Loss: 1.9847.
# Epoch 9/500 Iteration 1750 | Training Loss: 1.9424.
# Epoch 9/500 Iteration 1760 | Training Loss: 1.9873.
# Epoch 9/500 Iteration 1770 | Training Loss: 1.9932.
# Epoch 9/500 Iteration 1780 | Training Loss: 1.9508.
# Epoch 9/500 Iteration 1790 | Training Loss: 1.9912.
# Epoch 9/500 Iteration 1800 | Training Loss: 1.9753.
# Epoch 9/500 Iteration 1810 | Training Loss: 1.9760.
# Epoch 9/500 Iteration 1820 | Training Loss: 1.9343.
# Epoch 9/500 Iteration 1830 | Training Loss: 1.9732.
# Epoch 10/500 Iteration 1840 | Training Loss: 1.9912.
# Epoch 10/500 Iteration 1850 | Training Loss: 1.9416.
# Epoch 10/500 Iteration 1860 | Training Loss: 1.9995.
# Epoch 10/500 Iteration 1870 | Training Loss: 1.9868.
# Epoch 10/500 Iteration 1880 | Training Loss: 1.9496.
# Epoch 10/500 Iteration 1890 | Training Loss: 1.9746.
# Epoch 10/500 Iteration 1900 | Training Loss: 1.9513.
# Epoch 10/500 Iteration 1910 | Training Loss: 1.9506.
# Epoch 10/500 Iteration 1920 | Training Loss: 1.9336.
# Epoch 10/500 Iteration 1930 | Training Loss: 1.9300.
# Epoch 10/500 Iteration 1940 | Training Loss: 1.9288.
# Epoch 10/500 Iteration 1950 | Training Loss: 1.9412.
# Epoch 10/500 Iteration 1960 | Training Loss: 1.9519.
# Epoch 10/500 Iteration 1970 | Training Loss: 1.9485.
# Epoch 10/500 Iteration 1980 | Training Loss: 1.9286.
# Epoch 10/500 Iteration 1990 | Training Loss: 1.9670.
# Epoch 10/500 Iteration 2000 | Training Loss: 1.9212.
# Epoch 10/500 Iteration 2010 | Training Loss: 1.9599.
# Epoch 10/500 Iteration 2020 | Training Loss: 1.9405.
# Epoch 10/500 Iteration 2030 | Training Loss: 1.9151.
# Epoch 10/500 Iteration 2040 | Training Loss: 1.9595.
# Epoch 11/500 Iteration 2050 | Training Loss: 1.9293.
# Epoch 11/500 Iteration 2060 | Training Loss: 1.9293.
# Epoch 11/500 Iteration 2070 | Training Loss: 1.9392.
# Epoch 11/500 Iteration 2080 | Training Loss: 1.9192.
# Epoch 11/500 Iteration 2090 | Training Loss: 1.9274.
# Epoch 11/500 Iteration 2100 | Training Loss: 1.9460.
# Epoch 11/500 Iteration 2110 | Training Loss: 1.9357.
# Epoch 11/500 Iteration 2120 | Training Loss: 1.8938.
# Epoch 11/500 Iteration 2130 | Training Loss: 1.9051.
# Epoch 11/500 Iteration 2140 | Training Loss: 1.9085.
# Epoch 11/500 Iteration 2150 | Training Loss: 1.8712.
# Epoch 11/500 Iteration 2160 | Training Loss: 1.8929.
# Epoch 11/500 Iteration 2170 | Training Loss: 1.8707.
# Epoch 11/500 Iteration 2180 | Training Loss: 1.8923.
# Epoch 11/500 Iteration 2190 | Training Loss: 1.9061.
# Epoch 11/500 Iteration 2200 | Training Loss: 1.9555.
# Epoch 11/500 Iteration 2210 | Training Loss: 1.8909.
# Epoch 11/500 Iteration 2220 | Training Loss: 1.8940.
# Epoch 11/500 Iteration 2230 | Training Loss: 1.9114.
# Epoch 11/500 Iteration 2240 | Training Loss: 1.9175.
# Epoch 12/500 Iteration 2250 | Training Loss: 1.9097.
# Epoch 12/500 Iteration 2260 | Training Loss: 1.9038.
# Epoch 12/500 Iteration 2270 | Training Loss: 1.8937.
# Epoch 12/500 Iteration 2280 | Training Loss: 1.8740.
# Epoch 12/500 Iteration 2290 | Training Loss: 1.9242.
# Epoch 12/500 Iteration 2300 | Training Loss: 1.8689.
# Epoch 12/500 Iteration 2310 | Training Loss: 1.8830.
# Epoch 12/500 Iteration 2320 | Training Loss: 1.9298.
# Epoch 12/500 Iteration 2330 | Training Loss: 1.8645.
# Epoch 12/500 Iteration 2340 | Training Loss: 1.8688.
# Epoch 12/500 Iteration 2350 | Training Loss: 1.9016.
# Epoch 12/500 Iteration 2360 | Training Loss: 1.8856.
# Epoch 12/500 Iteration 2370 | Training Loss: 1.9001.
# Epoch 12/500 Iteration 2380 | Training Loss: 1.8961.
# Epoch 12/500 Iteration 2390 | Training Loss: 1.8654.
# Epoch 12/500 Iteration 2400 | Training Loss: 1.9208.
# Epoch 12/500 Iteration 2410 | Training Loss: 1.8729.
# Epoch 12/500 Iteration 2420 | Training Loss: 1.8924.
# Epoch 12/500 Iteration 2430 | Training Loss: 1.9201.
# Epoch 12/500 Iteration 2440 | Training Loss: 1.9209.
# Epoch 13/500 Iteration 2450 | Training Loss: 1.8906.
# Epoch 13/500 Iteration 2460 | Training Loss: 1.8794.
# Epoch 13/500 Iteration 2470 | Training Loss: 1.9044.
# Epoch 13/500 Iteration 2480 | Training Loss: 1.8438.
# Epoch 13/500 Iteration 2490 | Training Loss: 1.8674.
# Epoch 13/500 Iteration 2500 | Training Loss: 1.8489.
# Epoch 13/500 Iteration 2510 | Training Loss: 1.8421.
# Epoch 13/500 Iteration 2520 | Training Loss: 1.8422.
# Epoch 13/500 Iteration 2530 | Training Loss: 1.8776.
# Epoch 13/500 Iteration 2540 | Training Loss: 1.8711.
# Epoch 13/500 Iteration 2550 | Training Loss: 1.8165.
# Epoch 13/500 Iteration 2560 | Training Loss: 1.8510.
# Epoch 13/500 Iteration 2570 | Training Loss: 1.8516.
# Epoch 13/500 Iteration 2580 | Training Loss: 1.7999.
# Epoch 13/500 Iteration 2590 | Training Loss: 1.8469.
# Epoch 13/500 Iteration 2600 | Training Loss: 1.8368.
# Epoch 13/500 Iteration 2610 | Training Loss: 1.9009.
# Epoch 13/500 Iteration 2620 | Training Loss: 1.8643.
# Epoch 13/500 Iteration 2630 | Training Loss: 1.8617.
# Epoch 13/500 Iteration 2640 | Training Loss: 1.8821.
# Epoch 13/500 Iteration 2650 | Training Loss: 1.8874.
# Epoch 14/500 Iteration 2660 | Training Loss: 1.8374.
# Epoch 14/500 Iteration 2670 | Training Loss: 1.7828.
# Epoch 14/500 Iteration 2680 | Training Loss: 1.8422.
# Epoch 14/500 Iteration 2690 | Training Loss: 1.8419.
# Epoch 14/500 Iteration 2700 | Training Loss: 1.9038.
# Epoch 14/500 Iteration 2710 | Training Loss: 1.8349.
# Epoch 14/500 Iteration 2720 | Training Loss: 1.8792.
# Epoch 14/500 Iteration 2730 | Training Loss: 1.9071.
# Epoch 14/500 Iteration 2740 | Training Loss: 1.8291.
# Epoch 14/500 Iteration 2750 | Training Loss: 1.8354.
# Epoch 14/500 Iteration 2760 | Training Loss: 1.8339.
# Epoch 14/500 Iteration 2770 | Training Loss: 1.7903.
# Epoch 14/500 Iteration 2780 | Training Loss: 1.8461.
# Epoch 14/500 Iteration 2790 | Training Loss: 1.8469.
# Epoch 14/500 Iteration 2800 | Training Loss: 1.7865.
# Epoch 14/500 Iteration 2810 | Training Loss: 1.8371.
# Epoch 14/500 Iteration 2820 | Training Loss: 1.8392.
# Epoch 14/500 Iteration 2830 | Training Loss: 1.8430.
# Epoch 14/500 Iteration 2840 | Training Loss: 1.7997.
# Epoch 14/500 Iteration 2850 | Training Loss: 1.8440.
# Epoch 15/500 Iteration 2860 | Training Loss: 1.8585.
# Epoch 15/500 Iteration 2870 | Training Loss: 1.8295.
# Epoch 15/500 Iteration 2880 | Training Loss: 1.8713.
# Epoch 15/500 Iteration 2890 | Training Loss: 1.8259.
# Epoch 15/500 Iteration 2900 | Training Loss: 1.8192.
# Epoch 15/500 Iteration 2910 | Training Loss: 1.8564.
# Epoch 15/500 Iteration 2920 | Training Loss: 1.8282.
# Epoch 15/500 Iteration 2930 | Training Loss: 1.8153.
# Epoch 15/500 Iteration 2940 | Training Loss: 1.8207.
# Epoch 15/500 Iteration 2950 | Training Loss: 1.7991.
# Epoch 15/500 Iteration 2960 | Training Loss: 1.8053.
# Epoch 15/500 Iteration 2970 | Training Loss: 1.8181.
# Epoch 15/500 Iteration 2980 | Training Loss: 1.8184.
# Epoch 15/500 Iteration 2990 | Training Loss: 1.8178.
# Epoch 15/500 Iteration 3000 | Training Loss: 1.8005.
# Epoch 15/500 Iteration 3010 | Training Loss: 1.8316.
# Epoch 15/500 Iteration 3020 | Training Loss: 1.8047.
# Epoch 15/500 Iteration 3030 | Training Loss: 1.8497.
# Epoch 15/500 Iteration 3040 | Training Loss: 1.8096.
# Epoch 15/500 Iteration 3050 | Training Loss: 1.7807.
# Epoch 15/500 Iteration 3060 | Training Loss: 1.8446.
# Epoch 16/500 Iteration 3070 | Training Loss: 1.8331.
# Epoch 16/500 Iteration 3080 | Training Loss: 1.7959.
# Epoch 16/500 Iteration 3090 | Training Loss: 1.8087.
# Epoch 16/500 Iteration 3100 | Training Loss: 1.8233.
# Epoch 16/500 Iteration 3110 | Training Loss: 1.8087.
# Epoch 16/500 Iteration 3120 | Training Loss: 1.8275.
# Epoch 16/500 Iteration 3130 | Training Loss: 1.8297.
# Epoch 16/500 Iteration 3140 | Training Loss: 1.7721.
# Epoch 16/500 Iteration 3150 | Training Loss: 1.7852.
# Epoch 16/500 Iteration 3160 | Training Loss: 1.7855.
# Epoch 16/500 Iteration 3170 | Training Loss: 1.7465.
# Epoch 16/500 Iteration 3180 | Training Loss: 1.7764.
# Epoch 16/500 Iteration 3190 | Training Loss: 1.7605.
# Epoch 16/500 Iteration 3200 | Training Loss: 1.7830.
# Epoch 16/500 Iteration 3210 | Training Loss: 1.7968.
# Epoch 16/500 Iteration 3220 | Training Loss: 1.8351.
# Epoch 16/500 Iteration 3230 | Training Loss: 1.7830.
# Epoch 16/500 Iteration 3240 | Training Loss: 1.7855.
# Epoch 16/500 Iteration 3250 | Training Loss: 1.8077.
# Epoch 16/500 Iteration 3260 | Training Loss: 1.8112.
# Epoch 17/500 Iteration 3270 | Training Loss: 1.8045.
# Epoch 17/500 Iteration 3280 | Training Loss: 1.7947.
# Epoch 17/500 Iteration 3290 | Training Loss: 1.7890.
# Epoch 17/500 Iteration 3300 | Training Loss: 1.7635.
# Epoch 17/500 Iteration 3310 | Training Loss: 1.8201.
# Epoch 17/500 Iteration 3320 | Training Loss: 1.7686.
# Epoch 17/500 Iteration 3330 | Training Loss: 1.7887.
# Epoch 17/500 Iteration 3340 | Training Loss: 1.8295.
# Epoch 17/500 Iteration 3350 | Training Loss: 1.7801.
# Epoch 17/500 Iteration 3360 | Training Loss: 1.7708.
# Epoch 17/500 Iteration 3370 | Training Loss: 1.7900.
# Epoch 17/500 Iteration 3380 | Training Loss: 1.8050.
# Epoch 17/500 Iteration 3390 | Training Loss: 1.7945.
# Epoch 17/500 Iteration 3400 | Training Loss: 1.7798.
# Epoch 17/500 Iteration 3410 | Training Loss: 1.7592.
# Epoch 17/500 Iteration 3420 | Training Loss: 1.8083.
# Epoch 17/500 Iteration 3430 | Training Loss: 1.7726.
# Epoch 17/500 Iteration 3440 | Training Loss: 1.8002.
# Epoch 17/500 Iteration 3450 | Training Loss: 1.8258.
# Epoch 17/500 Iteration 3460 | Training Loss: 1.8173.
# Epoch 18/500 Iteration 3470 | Training Loss: 1.8026.
# Epoch 18/500 Iteration 3480 | Training Loss: 1.7732.
# Epoch 18/500 Iteration 3490 | Training Loss: 1.8126.
# Epoch 18/500 Iteration 3500 | Training Loss: 1.7450.
# Epoch 18/500 Iteration 3510 | Training Loss: 1.7663.
# Epoch 18/500 Iteration 3520 | Training Loss: 1.7551.
# Epoch 18/500 Iteration 3530 | Training Loss: 1.7405.
# Epoch 18/500 Iteration 3540 | Training Loss: 1.7440.
# Epoch 18/500 Iteration 3550 | Training Loss: 1.7844.
# Epoch 18/500 Iteration 3560 | Training Loss: 1.7587.
# Epoch 18/500 Iteration 3570 | Training Loss: 1.7082.
# Epoch 18/500 Iteration 3580 | Training Loss: 1.7559.
# Epoch 18/500 Iteration 3590 | Training Loss: 1.7534.
# Epoch 18/500 Iteration 3600 | Training Loss: 1.7094.
# Epoch 18/500 Iteration 3610 | Training Loss: 1.7576.
# Epoch 18/500 Iteration 3620 | Training Loss: 1.7344.
# Epoch 18/500 Iteration 3630 | Training Loss: 1.8189.
# Epoch 18/500 Iteration 3640 | Training Loss: 1.7576.
# Epoch 18/500 Iteration 3650 | Training Loss: 1.7594.
# Epoch 18/500 Iteration 3660 | Training Loss: 1.7774.
# Epoch 18/500 Iteration 3670 | Training Loss: 1.8102.
# Epoch 19/500 Iteration 3680 | Training Loss: 1.7408.
# Epoch 19/500 Iteration 3690 | Training Loss: 1.6929.
# Epoch 19/500 Iteration 3700 | Training Loss: 1.7639.
# Epoch 19/500 Iteration 3710 | Training Loss: 1.7492.
# Epoch 19/500 Iteration 3720 | Training Loss: 1.8182.
# Epoch 19/500 Iteration 3730 | Training Loss: 1.7564.
# Epoch 19/500 Iteration 3740 | Training Loss: 1.7916.
# Epoch 19/500 Iteration 3750 | Training Loss: 1.8364.
# Epoch 19/500 Iteration 3760 | Training Loss: 1.7465.
# Epoch 19/500 Iteration 3770 | Training Loss: 1.7572.
# Epoch 19/500 Iteration 3780 | Training Loss: 1.7606.
# Epoch 19/500 Iteration 3790 | Training Loss: 1.6978.
# Epoch 19/500 Iteration 3800 | Training Loss: 1.7599.
# Epoch 19/500 Iteration 3810 | Training Loss: 1.7704.
# Epoch 19/500 Iteration 3820 | Training Loss: 1.7078.
# Epoch 19/500 Iteration 3830 | Training Loss: 1.7582.
# Epoch 19/500 Iteration 3840 | Training Loss: 1.7699.
# Epoch 19/500 Iteration 3850 | Training Loss: 1.7468.
# Epoch 19/500 Iteration 3860 | Training Loss: 1.7221.
# Epoch 19/500 Iteration 3870 | Training Loss: 1.7583.
# Epoch 20/500 Iteration 3880 | Training Loss: 1.7936.
# Epoch 20/500 Iteration 3890 | Training Loss: 1.7316.
# Epoch 20/500 Iteration 3900 | Training Loss: 1.7930.
# Epoch 20/500 Iteration 3910 | Training Loss: 1.7436.
# Epoch 20/500 Iteration 3920 | Training Loss: 1.7365.
# Epoch 20/500 Iteration 3930 | Training Loss: 1.7801.
# Epoch 20/500 Iteration 3940 | Training Loss: 1.7438.
# Epoch 20/500 Iteration 3950 | Training Loss: 1.7361.
# Epoch 20/500 Iteration 3960 | Training Loss: 1.7203.
# Epoch 20/500 Iteration 3970 | Training Loss: 1.7121.
# Epoch 20/500 Iteration 3980 | Training Loss: 1.7231.
# Epoch 20/500 Iteration 3990 | Training Loss: 1.7313.
# Epoch 20/500 Iteration 4000 | Training Loss: 1.7352.
# Epoch 20/500 Iteration 4010 | Training Loss: 1.7290.
# Epoch 20/500 Iteration 4020 | Training Loss: 1.7079.
# Epoch 20/500 Iteration 4030 | Training Loss: 1.7481.
# Epoch 20/500 Iteration 4040 | Training Loss: 1.7210.
# Epoch 20/500 Iteration 4050 | Training Loss: 1.7725.
# Epoch 20/500 Iteration 4060 | Training Loss: 1.7257.
# Epoch 20/500 Iteration 4070 | Training Loss: 1.7198.
# Epoch 20/500 Iteration 4080 | Training Loss: 1.7739.
# Epoch 21/500 Iteration 4090 | Training Loss: 1.7584.
# Epoch 21/500 Iteration 4100 | Training Loss: 1.7272.
# Epoch 21/500 Iteration 4110 | Training Loss: 1.7412.
# Epoch 21/500 Iteration 4120 | Training Loss: 1.7445.
# Epoch 21/500 Iteration 4130 | Training Loss: 1.7298.
# Epoch 21/500 Iteration 4140 | Training Loss: 1.7569.
# Epoch 21/500 Iteration 4150 | Training Loss: 1.7413.
# Epoch 21/500 Iteration 4160 | Training Loss: 1.7099.
# Epoch 21/500 Iteration 4170 | Training Loss: 1.7101.
# Epoch 21/500 Iteration 4180 | Training Loss: 1.7243.
# Epoch 21/500 Iteration 4190 | Training Loss: 1.6762.
# Epoch 21/500 Iteration 4200 | Training Loss: 1.6980.
# Epoch 21/500 Iteration 4210 | Training Loss: 1.6965.
# Epoch 21/500 Iteration 4220 | Training Loss: 1.7016.
# Epoch 21/500 Iteration 4230 | Training Loss: 1.7197.
# Epoch 21/500 Iteration 4240 | Training Loss: 1.7670.
# Epoch 21/500 Iteration 4250 | Training Loss: 1.7183.
# Epoch 21/500 Iteration 4260 | Training Loss: 1.7124.
# Epoch 21/500 Iteration 4270 | Training Loss: 1.7248.
# Epoch 21/500 Iteration 4280 | Training Loss: 1.7363.
# Epoch 22/500 Iteration 4290 | Training Loss: 1.7343.
# Epoch 22/500 Iteration 4300 | Training Loss: 1.7236.
# Epoch 22/500 Iteration 4310 | Training Loss: 1.7126.
# Epoch 22/500 Iteration 4320 | Training Loss: 1.7048.
# Epoch 22/500 Iteration 4330 | Training Loss: 1.7507.
# Epoch 22/500 Iteration 4340 | Training Loss: 1.7045.
# Epoch 22/500 Iteration 4350 | Training Loss: 1.7207.
# Epoch 22/500 Iteration 4360 | Training Loss: 1.7542.
# Epoch 22/500 Iteration 4370 | Training Loss: 1.7152.
# Epoch 22/500 Iteration 4380 | Training Loss: 1.7000.
# Epoch 22/500 Iteration 4390 | Training Loss: 1.7180.
# Epoch 22/500 Iteration 4400 | Training Loss: 1.7251.
# Epoch 22/500 Iteration 4410 | Training Loss: 1.7047.
# Epoch 22/500 Iteration 4420 | Training Loss: 1.7282.
# Epoch 22/500 Iteration 4430 | Training Loss: 1.6902.
# Epoch 22/500 Iteration 4440 | Training Loss: 1.7338.
# Epoch 22/500 Iteration 4450 | Training Loss: 1.7055.
# Epoch 22/500 Iteration 4460 | Training Loss: 1.7180.
# Epoch 22/500 Iteration 4470 | Training Loss: 1.7441.
# Epoch 22/500 Iteration 4480 | Training Loss: 1.7569.
# Epoch 23/500 Iteration 4490 | Training Loss: 1.7525.
# Epoch 23/500 Iteration 4500 | Training Loss: 1.7122.
# Epoch 23/500 Iteration 4510 | Training Loss: 1.7485.
# Epoch 23/500 Iteration 4520 | Training Loss: 1.6703.
# Epoch 23/500 Iteration 4530 | Training Loss: 1.7031.
# Epoch 23/500 Iteration 4540 | Training Loss: 1.6936.
# Epoch 23/500 Iteration 4550 | Training Loss: 1.6724.
# Epoch 23/500 Iteration 4560 | Training Loss: 1.6860.
# Epoch 23/500 Iteration 4570 | Training Loss: 1.7286.
# Epoch 23/500 Iteration 4580 | Training Loss: 1.6968.
# Epoch 23/500 Iteration 4590 | Training Loss: 1.6403.
# Epoch 23/500 Iteration 4600 | Training Loss: 1.6896.
# Epoch 23/500 Iteration 4610 | Training Loss: 1.6819.
# Epoch 23/500 Iteration 4620 | Training Loss: 1.6415.
# Epoch 23/500 Iteration 4630 | Training Loss: 1.6877.
# Epoch 23/500 Iteration 4640 | Training Loss: 1.6776.
# Epoch 23/500 Iteration 4650 | Training Loss: 1.7395.
# Epoch 23/500 Iteration 4660 | Training Loss: 1.7033.
# Epoch 23/500 Iteration 4670 | Training Loss: 1.6855.
# Epoch 23/500 Iteration 4680 | Training Loss: 1.7517.
# Epoch 23/500 Iteration 4690 | Training Loss: 1.7447.
# Epoch 24/500 Iteration 4700 | Training Loss: 1.6788.
# Epoch 24/500 Iteration 4710 | Training Loss: 1.6191.
# Epoch 24/500 Iteration 4720 | Training Loss: 1.6954.
# Epoch 24/500 Iteration 4730 | Training Loss: 1.6932.
# Epoch 24/500 Iteration 4740 | Training Loss: 1.7583.
# Epoch 24/500 Iteration 4750 | Training Loss: 1.6929.
# Epoch 24/500 Iteration 4760 | Training Loss: 1.7391.
# Epoch 24/500 Iteration 4770 | Training Loss: 1.7522.
# Epoch 24/500 Iteration 4780 | Training Loss: 1.6975.
# Epoch 24/500 Iteration 4790 | Training Loss: 1.6887.
# Epoch 24/500 Iteration 4800 | Training Loss: 1.6882.
# Epoch 24/500 Iteration 4810 | Training Loss: 1.6324.
# Epoch 24/500 Iteration 4820 | Training Loss: 1.7009.
# Epoch 24/500 Iteration 4830 | Training Loss: 1.7017.
# Epoch 24/500 Iteration 4840 | Training Loss: 1.6450.
# Epoch 24/500 Iteration 4850 | Training Loss: 1.6985.
# Epoch 24/500 Iteration 4860 | Training Loss: 1.7043.
# Epoch 24/500 Iteration 4870 | Training Loss: 1.6890.
# Epoch 24/500 Iteration 4880 | Training Loss: 1.6666.
# Epoch 24/500 Iteration 4890 | Training Loss: 1.6837.
# Epoch 25/500 Iteration 4900 | Training Loss: 1.7306.
# Epoch 25/500 Iteration 4910 | Training Loss: 1.6775.
# Epoch 25/500 Iteration 4920 | Training Loss: 1.7514.
# Epoch 25/500 Iteration 4930 | Training Loss: 1.6790.
# Epoch 25/500 Iteration 4940 | Training Loss: 1.6842.
# Epoch 25/500 Iteration 4950 | Training Loss: 1.7183.
# Epoch 25/500 Iteration 4960 | Training Loss: 1.6837.
# Epoch 25/500 Iteration 4970 | Training Loss: 1.6762.
# Epoch 25/500 Iteration 4980 | Training Loss: 1.6764.
# Epoch 25/500 Iteration 4990 | Training Loss: 1.6478.
# Epoch 25/500 Iteration 5000 | Training Loss: 1.6702.
# Epoch 25/500 Iteration 5010 | Training Loss: 1.6642.
# Epoch 25/500 Iteration 5020 | Training Loss: 1.6735.
# Epoch 25/500 Iteration 5030 | Training Loss: 1.6771.
# Epoch 25/500 Iteration 5040 | Training Loss: 1.6485.
# Epoch 25/500 Iteration 5050 | Training Loss: 1.6914.
# Epoch 25/500 Iteration 5060 | Training Loss: 1.6713.
# Epoch 25/500 Iteration 5070 | Training Loss: 1.7230.
# Epoch 25/500 Iteration 5080 | Training Loss: 1.6813.
# Epoch 25/500 Iteration 5090 | Training Loss: 1.6590.
# Epoch 25/500 Iteration 5100 | Training Loss: 1.7232.
# Epoch 26/500 Iteration 5110 | Training Loss: 1.6966.
# Epoch 26/500 Iteration 5120 | Training Loss: 1.6665.
# Epoch 26/500 Iteration 5130 | Training Loss: 1.6634.
# Epoch 26/500 Iteration 5140 | Training Loss: 1.6884.
# Epoch 26/500 Iteration 5150 | Training Loss: 1.6733.
# Epoch 26/500 Iteration 5160 | Training Loss: 1.6917.
# Epoch 26/500 Iteration 5170 | Training Loss: 1.6873.
# Epoch 26/500 Iteration 5180 | Training Loss: 1.6562.
# Epoch 26/500 Iteration 5190 | Training Loss: 1.6673.
# Epoch 26/500 Iteration 5200 | Training Loss: 1.6701.
# Epoch 26/500 Iteration 5210 | Training Loss: 1.6054.
# Epoch 26/500 Iteration 5220 | Training Loss: 1.6508.
# Epoch 26/500 Iteration 5230 | Training Loss: 1.6293.
# Epoch 26/500 Iteration 5240 | Training Loss: 1.6609.
# Epoch 26/500 Iteration 5250 | Training Loss: 1.6605.
# Epoch 26/500 Iteration 5260 | Training Loss: 1.7124.
# Epoch 26/500 Iteration 5270 | Training Loss: 1.6647.
# Epoch 26/500 Iteration 5280 | Training Loss: 1.6722.
# Epoch 26/500 Iteration 5290 | Training Loss: 1.6667.
# Epoch 26/500 Iteration 5300 | Training Loss: 1.6726.
# Epoch 27/500 Iteration 5310 | Training Loss: 1.6939.
# Epoch 27/500 Iteration 5320 | Training Loss: 1.6811.
# Epoch 27/500 Iteration 5330 | Training Loss: 1.6662.
# Epoch 27/500 Iteration 5340 | Training Loss: 1.6456.
# Epoch 27/500 Iteration 5350 | Training Loss: 1.6791.
# Epoch 27/500 Iteration 5360 | Training Loss: 1.6385.
# Epoch 27/500 Iteration 5370 | Training Loss: 1.6783.
# Epoch 27/500 Iteration 5380 | Training Loss: 1.6993.
# Epoch 27/500 Iteration 5390 | Training Loss: 1.6549.
# Epoch 27/500 Iteration 5400 | Training Loss: 1.6494.
# Epoch 27/500 Iteration 5410 | Training Loss: 1.6614.
# Epoch 27/500 Iteration 5420 | Training Loss: 1.6744.
# Epoch 27/500 Iteration 5430 | Training Loss: 1.6656.
# Epoch 27/500 Iteration 5440 | Training Loss: 1.6627.
# Epoch 27/500 Iteration 5450 | Training Loss: 1.6384.
# Epoch 27/500 Iteration 5460 | Training Loss: 1.6793.
# Epoch 27/500 Iteration 5470 | Training Loss: 1.6568.
# Epoch 27/500 Iteration 5480 | Training Loss: 1.6785.
# Epoch 27/500 Iteration 5490 | Training Loss: 1.6925.
# Epoch 27/500 Iteration 5500 | Training Loss: 1.7129.
# Epoch 28/500 Iteration 5510 | Training Loss: 1.6887.
# Epoch 28/500 Iteration 5520 | Training Loss: 1.6596.
# Epoch 28/500 Iteration 5530 | Training Loss: 1.7006.
# Epoch 28/500 Iteration 5540 | Training Loss: 1.6234.
# Epoch 28/500 Iteration 5550 | Training Loss: 1.6662.
# Epoch 28/500 Iteration 5560 | Training Loss: 1.6434.
# Epoch 28/500 Iteration 5570 | Training Loss: 1.6323.
# Epoch 28/500 Iteration 5580 | Training Loss: 1.6327.
# Epoch 28/500 Iteration 5590 | Training Loss: 1.6775.
# Epoch 28/500 Iteration 5600 | Training Loss: 1.6557.
# Epoch 28/500 Iteration 5610 | Training Loss: 1.5941.
# Epoch 28/500 Iteration 5620 | Training Loss: 1.6368.
# Epoch 28/500 Iteration 5630 | Training Loss: 1.6440.
# Epoch 28/500 Iteration 5640 | Training Loss: 1.6046.
# Epoch 28/500 Iteration 5650 | Training Loss: 1.6344.
# Epoch 28/500 Iteration 5660 | Training Loss: 1.6268.
# Epoch 28/500 Iteration 5670 | Training Loss: 1.6869.
# Epoch 28/500 Iteration 5680 | Training Loss: 1.6530.
# Epoch 28/500 Iteration 5690 | Training Loss: 1.6618.
# Epoch 28/500 Iteration 5700 | Training Loss: 1.6850.
# Epoch 28/500 Iteration 5710 | Training Loss: 1.6955.
# Epoch 29/500 Iteration 5720 | Training Loss: 1.6447.
# Epoch 29/500 Iteration 5730 | Training Loss: 1.5728.
# Epoch 29/500 Iteration 5740 | Training Loss: 1.6646.
# Epoch 29/500 Iteration 5750 | Training Loss: 1.6510.
# Epoch 29/500 Iteration 5760 | Training Loss: 1.7267.
# Epoch 29/500 Iteration 5770 | Training Loss: 1.6574.
# Epoch 29/500 Iteration 5780 | Training Loss: 1.6858.
# Epoch 29/500 Iteration 5790 | Training Loss: 1.7080.
# Epoch 29/500 Iteration 5800 | Training Loss: 1.6551.
# Epoch 29/500 Iteration 5810 | Training Loss: 1.6361.
# Epoch 29/500 Iteration 5820 | Training Loss: 1.6583.
# Epoch 29/500 Iteration 5830 | Training Loss: 1.6042.
# Epoch 29/500 Iteration 5840 | Training Loss: 1.6376.
# Epoch 29/500 Iteration 5850 | Training Loss: 1.6536.
# Epoch 29/500 Iteration 5860 | Training Loss: 1.5970.
# Epoch 29/500 Iteration 5870 | Training Loss: 1.6478.
# Epoch 29/500 Iteration 5880 | Training Loss: 1.6593.
# Epoch 29/500 Iteration 5890 | Training Loss: 1.6511.
# Epoch 29/500 Iteration 5900 | Training Loss: 1.6187.
# Epoch 29/500 Iteration 5910 | Training Loss: 1.6456.
# Epoch 30/500 Iteration 5920 | Training Loss: 1.6833.
# Epoch 30/500 Iteration 5930 | Training Loss: 1.6388.
# Epoch 30/500 Iteration 5940 | Training Loss: 1.6882.
# Epoch 30/500 Iteration 5950 | Training Loss: 1.6388.
# Epoch 30/500 Iteration 5960 | Training Loss: 1.6486.
# Epoch 30/500 Iteration 5970 | Training Loss: 1.6837.
# Epoch 30/500 Iteration 5980 | Training Loss: 1.6325.
# Epoch 30/500 Iteration 5990 | Training Loss: 1.6449.
# Epoch 30/500 Iteration 6000 | Training Loss: 1.6311.
# Epoch 30/500 Iteration 6010 | Training Loss: 1.6081.
# Epoch 30/500 Iteration 6020 | Training Loss: 1.6322.
# Epoch 30/500 Iteration 6030 | Training Loss: 1.6261.
# Epoch 30/500 Iteration 6040 | Training Loss: 1.6491.
# Epoch 30/500 Iteration 6050 | Training Loss: 1.6222.
# Epoch 30/500 Iteration 6060 | Training Loss: 1.6234.
# Epoch 30/500 Iteration 6070 | Training Loss: 1.6544.
# Epoch 30/500 Iteration 6080 | Training Loss: 1.6364.
# Epoch 30/500 Iteration 6090 | Training Loss: 1.6730.
# Epoch 30/500 Iteration 6100 | Training Loss: 1.6244.
# Epoch 30/500 Iteration 6110 | Training Loss: 1.6091.
# Epoch 30/500 Iteration 6120 | Training Loss: 1.6636.
# Epoch 31/500 Iteration 6130 | Training Loss: 1.6478.
# Epoch 31/500 Iteration 6140 | Training Loss: 1.6213.
# Epoch 31/500 Iteration 6150 | Training Loss: 1.6172.
# Epoch 31/500 Iteration 6160 | Training Loss: 1.6458.
# Epoch 31/500 Iteration 6170 | Training Loss: 1.6252.
# Epoch 31/500 Iteration 6180 | Training Loss: 1.6569.
# Epoch 31/500 Iteration 6190 | Training Loss: 1.6547.
# Epoch 31/500 Iteration 6200 | Training Loss: 1.6071.
# Epoch 31/500 Iteration 6210 | Training Loss: 1.6288.
# Epoch 31/500 Iteration 6220 | Training Loss: 1.6217.
# Epoch 31/500 Iteration 6230 | Training Loss: 1.5821.
# Epoch 31/500 Iteration 6240 | Training Loss: 1.6141.
# Epoch 31/500 Iteration 6250 | Training Loss: 1.5915.
# Epoch 31/500 Iteration 6260 | Training Loss: 1.6144.
# Epoch 31/500 Iteration 6270 | Training Loss: 1.6392.
# Epoch 31/500 Iteration 6280 | Training Loss: 1.6704.
# Epoch 31/500 Iteration 6290 | Training Loss: 1.6262.
# Epoch 31/500 Iteration 6300 | Training Loss: 1.6363.
# Epoch 31/500 Iteration 6310 | Training Loss: 1.6296.
# Epoch 31/500 Iteration 6320 | Training Loss: 1.6295.
# Epoch 32/500 Iteration 6330 | Training Loss: 1.6538.
# Epoch 32/500 Iteration 6340 | Training Loss: 1.6223.
# Epoch 32/500 Iteration 6350 | Training Loss: 1.6233.
# Epoch 32/500 Iteration 6360 | Training Loss: 1.5982.
# Epoch 32/500 Iteration 6370 | Training Loss: 1.6420.
# Epoch 32/500 Iteration 6380 | Training Loss: 1.5985.
# Epoch 32/500 Iteration 6390 | Training Loss: 1.6369.
# Epoch 32/500 Iteration 6400 | Training Loss: 1.6757.
# Epoch 32/500 Iteration 6410 | Training Loss: 1.6202.
# Epoch 32/500 Iteration 6420 | Training Loss: 1.6067.
# Epoch 32/500 Iteration 6430 | Training Loss: 1.6253.
# Epoch 32/500 Iteration 6440 | Training Loss: 1.6244.
# Epoch 32/500 Iteration 6450 | Training Loss: 1.6230.
# Epoch 32/500 Iteration 6460 | Training Loss: 1.6270.
# Epoch 32/500 Iteration 6470 | Training Loss: 1.5903.
# Epoch 32/500 Iteration 6480 | Training Loss: 1.6406.
# Epoch 32/500 Iteration 6490 | Training Loss: 1.6248.
# Epoch 32/500 Iteration 6500 | Training Loss: 1.6321.
# Epoch 32/500 Iteration 6510 | Training Loss: 1.6482.
# Epoch 32/500 Iteration 6520 | Training Loss: 1.6699.
# Epoch 33/500 Iteration 6530 | Training Loss: 1.6514.
# Epoch 33/500 Iteration 6540 | Training Loss: 1.6267.
# Epoch 33/500 Iteration 6550 | Training Loss: 1.6683.
# Epoch 33/500 Iteration 6560 | Training Loss: 1.5930.
# Epoch 33/500 Iteration 6570 | Training Loss: 1.6078.
# Epoch 33/500 Iteration 6580 | Training Loss: 1.6092.
# Epoch 33/500 Iteration 6590 | Training Loss: 1.5931.
# Epoch 33/500 Iteration 6600 | Training Loss: 1.5902.
# Epoch 33/500 Iteration 6610 | Training Loss: 1.6485.
# Epoch 33/500 Iteration 6620 | Training Loss: 1.6119.
# Epoch 33/500 Iteration 6630 | Training Loss: 1.5644.
# Epoch 33/500 Iteration 6640 | Training Loss: 1.5987.
# Epoch 33/500 Iteration 6650 | Training Loss: 1.6052.
# Epoch 33/500 Iteration 6660 | Training Loss: 1.5672.
# Epoch 33/500 Iteration 6670 | Training Loss: 1.5895.
# Epoch 33/500 Iteration 6680 | Training Loss: 1.5865.
# Epoch 33/500 Iteration 6690 | Training Loss: 1.6600.
# Epoch 33/500 Iteration 6700 | Training Loss: 1.6326.
# Epoch 33/500 Iteration 6710 | Training Loss: 1.6188.
# Epoch 33/500 Iteration 6720 | Training Loss: 1.6416.
# Epoch 33/500 Iteration 6730 | Training Loss: 1.6644.
# Epoch 34/500 Iteration 6740 | Training Loss: 1.6137.
# Epoch 34/500 Iteration 6750 | Training Loss: 1.5453.
# Epoch 34/500 Iteration 6760 | Training Loss: 1.6176.
# Epoch 34/500 Iteration 6770 | Training Loss: 1.6096.
# Epoch 34/500 Iteration 6780 | Training Loss: 1.6879.
# Epoch 34/500 Iteration 6790 | Training Loss: 1.6083.
# Epoch 34/500 Iteration 6800 | Training Loss: 1.6489.
# Epoch 34/500 Iteration 6810 | Training Loss: 1.6714.
# Epoch 34/500 Iteration 6820 | Training Loss: 1.6148.
# Epoch 34/500 Iteration 6830 | Training Loss: 1.6082.
# Epoch 34/500 Iteration 6840 | Training Loss: 1.6128.
# Epoch 34/500 Iteration 6850 | Training Loss: 1.5625.
# Epoch 34/500 Iteration 6860 | Training Loss: 1.6194.
# Epoch 34/500 Iteration 6870 | Training Loss: 1.6192.
# Epoch 34/500 Iteration 6880 | Training Loss: 1.5539.
# Epoch 34/500 Iteration 6890 | Training Loss: 1.6223.
# Epoch 34/500 Iteration 6900 | Training Loss: 1.6135.
# Epoch 34/500 Iteration 6910 | Training Loss: 1.6274.
# Epoch 34/500 Iteration 6920 | Training Loss: 1.5856.
# Epoch 34/500 Iteration 6930 | Training Loss: 1.6326.
# Epoch 35/500 Iteration 6940 | Training Loss: 1.6547.
# Epoch 35/500 Iteration 6950 | Training Loss: 1.5966.
# Epoch 35/500 Iteration 6960 | Training Loss: 1.6498.
# Epoch 35/500 Iteration 6970 | Training Loss: 1.6109.
# Epoch 35/500 Iteration 6980 | Training Loss: 1.6075.
# Epoch 35/500 Iteration 6990 | Training Loss: 1.6415.
# Epoch 35/500 Iteration 7000 | Training Loss: 1.5972.
# Epoch 35/500 Iteration 7010 | Training Loss: 1.6004.
# Epoch 35/500 Iteration 7020 | Training Loss: 1.5956.
# Epoch 35/500 Iteration 7030 | Training Loss: 1.5720.
# Epoch 35/500 Iteration 7040 | Training Loss: 1.6052.
# Epoch 35/500 Iteration 7050 | Training Loss: 1.5895.
# Epoch 35/500 Iteration 7060 | Training Loss: 1.6087.
# Epoch 35/500 Iteration 7070 | Training Loss: 1.5971.
# Epoch 35/500 Iteration 7080 | Training Loss: 1.5819.
# Epoch 35/500 Iteration 7090 | Training Loss: 1.6081.
# Epoch 35/500 Iteration 7100 | Training Loss: 1.5941.
# Epoch 35/500 Iteration 7110 | Training Loss: 1.6385.
# Epoch 35/500 Iteration 7120 | Training Loss: 1.5952.
# Epoch 35/500 Iteration 7130 | Training Loss: 1.5688.
# Epoch 35/500 Iteration 7140 | Training Loss: 1.6267.
# Epoch 36/500 Iteration 7150 | Training Loss: 1.6184.
# Epoch 36/500 Iteration 7160 | Training Loss: 1.5863.
# Epoch 36/500 Iteration 7170 | Training Loss: 1.5936.
# Epoch 36/500 Iteration 7180 | Training Loss: 1.6243.
# Epoch 36/500 Iteration 7190 | Training Loss: 1.5948.
# Epoch 36/500 Iteration 7200 | Training Loss: 1.6217.
# Epoch 36/500 Iteration 7210 | Training Loss: 1.6099.
# Epoch 36/500 Iteration 7220 | Training Loss: 1.5656.
# Epoch 36/500 Iteration 7230 | Training Loss: 1.5930.
# Epoch 36/500 Iteration 7240 | Training Loss: 1.6081.
# Epoch 36/500 Iteration 7250 | Training Loss: 1.5407.
# Epoch 36/500 Iteration 7260 | Training Loss: 1.5800.
# Epoch 36/500 Iteration 7270 | Training Loss: 1.5692.
# Epoch 36/500 Iteration 7280 | Training Loss: 1.5855.
# Epoch 36/500 Iteration 7290 | Training Loss: 1.5973.
# Epoch 36/500 Iteration 7300 | Training Loss: 1.6297.
# Epoch 36/500 Iteration 7310 | Training Loss: 1.5830.
# Epoch 36/500 Iteration 7320 | Training Loss: 1.6135.
# Epoch 36/500 Iteration 7330 | Training Loss: 1.6021.
# Epoch 36/500 Iteration 7340 | Training Loss: 1.6072.
# Epoch 37/500 Iteration 7350 | Training Loss: 1.6161.
# Epoch 37/500 Iteration 7360 | Training Loss: 1.6061.
# Epoch 37/500 Iteration 7370 | Training Loss: 1.5963.
# Epoch 37/500 Iteration 7380 | Training Loss: 1.5724.
# Epoch 37/500 Iteration 7390 | Training Loss: 1.6086.
# Epoch 37/500 Iteration 7400 | Training Loss: 1.5770.
# Epoch 37/500 Iteration 7410 | Training Loss: 1.5939.
# Epoch 37/500 Iteration 7420 | Training Loss: 1.6280.
# Epoch 37/500 Iteration 7430 | Training Loss: 1.5774.
# Epoch 37/500 Iteration 7440 | Training Loss: 1.5764.
# Epoch 37/500 Iteration 7450 | Training Loss: 1.5856.
# Epoch 37/500 Iteration 7460 | Training Loss: 1.5948.
# Epoch 37/500 Iteration 7470 | Training Loss: 1.5801.
# Epoch 37/500 Iteration 7480 | Training Loss: 1.5928.
# Epoch 37/500 Iteration 7490 | Training Loss: 1.5725.
# Epoch 37/500 Iteration 7500 | Training Loss: 1.6158.
# Epoch 37/500 Iteration 7510 | Training Loss: 1.5895.
# Epoch 37/500 Iteration 7520 | Training Loss: 1.6228.
# Epoch 37/500 Iteration 7530 | Training Loss: 1.6244.
# Epoch 37/500 Iteration 7540 | Training Loss: 1.6144.
# Epoch 38/500 Iteration 7550 | Training Loss: 1.6241.
# Epoch 38/500 Iteration 7560 | Training Loss: 1.6104.
# Epoch 38/500 Iteration 7570 | Training Loss: 1.6294.
# Epoch 38/500 Iteration 7580 | Training Loss: 1.5579.
# Epoch 38/500 Iteration 7590 | Training Loss: 1.5891.
# Epoch 38/500 Iteration 7600 | Training Loss: 1.5854.
# Epoch 38/500 Iteration 7610 | Training Loss: 1.5642.
# Epoch 38/500 Iteration 7620 | Training Loss: 1.5691.
# Epoch 38/500 Iteration 7630 | Training Loss: 1.6105.
# Epoch 38/500 Iteration 7640 | Training Loss: 1.5946.
# Epoch 38/500 Iteration 7650 | Training Loss: 1.5322.
# Epoch 38/500 Iteration 7660 | Training Loss: 1.5601.
# Epoch 38/500 Iteration 7670 | Training Loss: 1.5760.
# Epoch 38/500 Iteration 7680 | Training Loss: 1.5430.
# Epoch 38/500 Iteration 7690 | Training Loss: 1.5734.
# Epoch 38/500 Iteration 7700 | Training Loss: 1.5547.
# Epoch 38/500 Iteration 7710 | Training Loss: 1.6274.
# Epoch 38/500 Iteration 7720 | Training Loss: 1.5807.
# Epoch 38/500 Iteration 7730 | Training Loss: 1.5879.
# Epoch 38/500 Iteration 7740 | Training Loss: 1.6220.
# Epoch 38/500 Iteration 7750 | Training Loss: 1.6271.
# Epoch 39/500 Iteration 7760 | Training Loss: 1.5872.
# Epoch 39/500 Iteration 7770 | Training Loss: 1.5157.
# Epoch 39/500 Iteration 7780 | Training Loss: 1.5824.
# Epoch 39/500 Iteration 7790 | Training Loss: 1.5640.
# Epoch 39/500 Iteration 7800 | Training Loss: 1.6525.
# Epoch 39/500 Iteration 7810 | Training Loss: 1.5801.
# Epoch 39/500 Iteration 7820 | Training Loss: 1.6209.
# Epoch 39/500 Iteration 7830 | Training Loss: 1.6291.
# Epoch 39/500 Iteration 7840 | Training Loss: 1.5935.
# Epoch 39/500 Iteration 7850 | Training Loss: 1.5782.
# Epoch 39/500 Iteration 7860 | Training Loss: 1.5907.
# Epoch 39/500 Iteration 7870 | Training Loss: 1.5186.
# Epoch 39/500 Iteration 7880 | Training Loss: 1.5910.
# Epoch 39/500 Iteration 7890 | Training Loss: 1.5947.
# Epoch 39/500 Iteration 7900 | Training Loss: 1.5325.
# Epoch 39/500 Iteration 7910 | Training Loss: 1.5824.
# Epoch 39/500 Iteration 7920 | Training Loss: 1.5940.
# Epoch 39/500 Iteration 7930 | Training Loss: 1.5832.
# Epoch 39/500 Iteration 7940 | Training Loss: 1.5601.
# Epoch 39/500 Iteration 7950 | Training Loss: 1.5769.
# Epoch 40/500 Iteration 7960 | Training Loss: 1.6248.
# Epoch 40/500 Iteration 7970 | Training Loss: 1.5819.
# Epoch 40/500 Iteration 7980 | Training Loss: 1.6126.
# Epoch 40/500 Iteration 7990 | Training Loss: 1.5743.
# Epoch 40/500 Iteration 8000 | Training Loss: 1.5825.
# Epoch 40/500 Iteration 8010 | Training Loss: 1.6181.
# Epoch 40/500 Iteration 8020 | Training Loss: 1.5674.
# Epoch 40/500 Iteration 8030 | Training Loss: 1.5731.
# Epoch 40/500 Iteration 8040 | Training Loss: 1.5552.
# Epoch 40/500 Iteration 8050 | Training Loss: 1.5413.
# Epoch 40/500 Iteration 8060 | Training Loss: 1.5611.
# Epoch 40/500 Iteration 8070 | Training Loss: 1.5577.
# Epoch 40/500 Iteration 8080 | Training Loss: 1.5783.
# Epoch 40/500 Iteration 8090 | Training Loss: 1.5829.
# Epoch 40/500 Iteration 8100 | Training Loss: 1.5598.
# Epoch 40/500 Iteration 8110 | Training Loss: 1.5839.
# Epoch 40/500 Iteration 8120 | Training Loss: 1.5706.
# Epoch 40/500 Iteration 8130 | Training Loss: 1.6169.
# Epoch 40/500 Iteration 8140 | Training Loss: 1.5720.
# Epoch 40/500 Iteration 8150 | Training Loss: 1.5577.
# Epoch 40/500 Iteration 8160 | Training Loss: 1.6131.
# Epoch 41/500 Iteration 8170 | Training Loss: 1.5982.
# Epoch 41/500 Iteration 8180 | Training Loss: 1.5561.
# Epoch 41/500 Iteration 8190 | Training Loss: 1.5634.
# Epoch 41/500 Iteration 8200 | Training Loss: 1.5942.
# Epoch 41/500 Iteration 8210 | Training Loss: 1.5647.
# Epoch 41/500 Iteration 8220 | Training Loss: 1.5927.
# Epoch 41/500 Iteration 8230 | Training Loss: 1.5966.
# Epoch 41/500 Iteration 8240 | Training Loss: 1.5438.
# Epoch 41/500 Iteration 8250 | Training Loss: 1.5663.
# Epoch 41/500 Iteration 8260 | Training Loss: 1.5794.
# Epoch 41/500 Iteration 8270 | Training Loss: 1.5164.
# Epoch 41/500 Iteration 8280 | Training Loss: 1.5618.
# Epoch 41/500 Iteration 8290 | Training Loss: 1.5398.
# Epoch 41/500 Iteration 8300 | Training Loss: 1.5581.
# Epoch 41/500 Iteration 8310 | Training Loss: 1.5837.
# Epoch 41/500 Iteration 8320 | Training Loss: 1.6143.
# Epoch 41/500 Iteration 8330 | Training Loss: 1.5640.
# Epoch 41/500 Iteration 8340 | Training Loss: 1.5842.
# Epoch 41/500 Iteration 8350 | Training Loss: 1.5689.
# Epoch 41/500 Iteration 8360 | Training Loss: 1.5786.
# Epoch 42/500 Iteration 8370 | Training Loss: 1.5832.
# Epoch 42/500 Iteration 8380 | Training Loss: 1.5865.
# Epoch 42/500 Iteration 8390 | Training Loss: 1.5449.
# Epoch 42/500 Iteration 8400 | Training Loss: 1.5491.
# Epoch 42/500 Iteration 8410 | Training Loss: 1.5866.
# Epoch 42/500 Iteration 8420 | Training Loss: 1.5335.
# Epoch 42/500 Iteration 8430 | Training Loss: 1.5766.
# Epoch 42/500 Iteration 8440 | Training Loss: 1.5966.
# Epoch 42/500 Iteration 8450 | Training Loss: 1.5613.
# Epoch 42/500 Iteration 8460 | Training Loss: 1.5545.
# Epoch 42/500 Iteration 8470 | Training Loss: 1.5655.
# Epoch 42/500 Iteration 8480 | Training Loss: 1.5753.
# Epoch 42/500 Iteration 8490 | Training Loss: 1.5588.
# Epoch 42/500 Iteration 8500 | Training Loss: 1.5797.
# Epoch 42/500 Iteration 8510 | Training Loss: 1.5299.
# Epoch 42/500 Iteration 8520 | Training Loss: 1.5956.
# Epoch 42/500 Iteration 8530 | Training Loss: 1.5736.
# Epoch 42/500 Iteration 8540 | Training Loss: 1.5901.
# Epoch 42/500 Iteration 8550 | Training Loss: 1.5922.
# Epoch 42/500 Iteration 8560 | Training Loss: 1.6060.
# Epoch 43/500 Iteration 8570 | Training Loss: 1.5923.
# Epoch 43/500 Iteration 8580 | Training Loss: 1.5809.
# Epoch 43/500 Iteration 8590 | Training Loss: 1.6117.
# Epoch 43/500 Iteration 8600 | Training Loss: 1.5378.
# Epoch 43/500 Iteration 8610 | Training Loss: 1.5738.
# Epoch 43/500 Iteration 8620 | Training Loss: 1.5652.
# Epoch 43/500 Iteration 8630 | Training Loss: 1.5365.
# Epoch 43/500 Iteration 8640 | Training Loss: 1.5452.
# Epoch 43/500 Iteration 8650 | Training Loss: 1.5856.
# Epoch 43/500 Iteration 8660 | Training Loss: 1.5622.
# Epoch 43/500 Iteration 8670 | Training Loss: 1.5188.
# Epoch 43/500 Iteration 8680 | Training Loss: 1.5387.
# Epoch 43/500 Iteration 8690 | Training Loss: 1.5509.
# Epoch 43/500 Iteration 8700 | Training Loss: 1.5140.
# Epoch 43/500 Iteration 8710 | Training Loss: 1.5514.
# Epoch 43/500 Iteration 8720 | Training Loss: 1.5345.
# Epoch 43/500 Iteration 8730 | Training Loss: 1.6108.
# Epoch 43/500 Iteration 8740 | Training Loss: 1.5658.
# Epoch 43/500 Iteration 8750 | Training Loss: 1.5615.
# Epoch 43/500 Iteration 8760 | Training Loss: 1.6058.
# Epoch 43/500 Iteration 8770 | Training Loss: 1.6089.
# Epoch 44/500 Iteration 8780 | Training Loss: 1.5645.
# Epoch 44/500 Iteration 8790 | Training Loss: 1.4830.
# Epoch 44/500 Iteration 8800 | Training Loss: 1.5758.
# Epoch 44/500 Iteration 8810 | Training Loss: 1.5499.
# Epoch 44/500 Iteration 8820 | Training Loss: 1.6428.
# Epoch 44/500 Iteration 8830 | Training Loss: 1.5474.
# Epoch 44/500 Iteration 8840 | Training Loss: 1.6065.
# Epoch 44/500 Iteration 8850 | Training Loss: 1.6053.
# Epoch 44/500 Iteration 8860 | Training Loss: 1.5592.
# Epoch 44/500 Iteration 8870 | Training Loss: 1.5430.
# Epoch 44/500 Iteration 8880 | Training Loss: 1.5540.
# Epoch 44/500 Iteration 8890 | Training Loss: 1.5189.
# Epoch 44/500 Iteration 8900 | Training Loss: 1.5624.
# Epoch 44/500 Iteration 8910 | Training Loss: 1.5780.
# Epoch 44/500 Iteration 8920 | Training Loss: 1.5043.
# Epoch 44/500 Iteration 8930 | Training Loss: 1.5484.
# Epoch 44/500 Iteration 8940 | Training Loss: 1.5601.
# Epoch 44/500 Iteration 8950 | Training Loss: 1.5714.
# Epoch 44/500 Iteration 8960 | Training Loss: 1.5377.
# Epoch 44/500 Iteration 8970 | Training Loss: 1.5735.
# Epoch 45/500 Iteration 8980 | Training Loss: 1.6198.
# Epoch 45/500 Iteration 8990 | Training Loss: 1.5607.
# Epoch 45/500 Iteration 9000 | Training Loss: 1.5925.
# Epoch 45/500 Iteration 9010 | Training Loss: 1.5391.
# Epoch 45/500 Iteration 9020 | Training Loss: 1.5418.
# Epoch 45/500 Iteration 9030 | Training Loss: 1.5917.
# Epoch 45/500 Iteration 9040 | Training Loss: 1.5529.
# Epoch 45/500 Iteration 9050 | Training Loss: 1.5490.
# Epoch 45/500 Iteration 9060 | Training Loss: 1.5480.
# Epoch 45/500 Iteration 9070 | Training Loss: 1.5155.
# Epoch 45/500 Iteration 9080 | Training Loss: 1.5396.
# Epoch 45/500 Iteration 9090 | Training Loss: 1.5406.
# ...
# Epoch 486/500 Iteration 99140 | Training Loss: 1.3735.
# Epoch 487/500 Iteration 99150 | Training Loss: 1.3544.
# Epoch 487/500 Iteration 99160 | Training Loss: 1.3614.
# Epoch 487/500 Iteration 99170 | Training Loss: 1.3248.
# Epoch 487/500 Iteration 99180 | Training Loss: 1.3335.
# Epoch 487/500 Iteration 99190 | Training Loss: 1.3603.
# Epoch 487/500 Iteration 99200 | Training Loss: 1.3293.
# Epoch 487/500 Iteration 99210 | Training Loss: 1.3350.
# Epoch 487/500 Iteration 99220 | Training Loss: 1.3627.
# Epoch 487/500 Iteration 99230 | Training Loss: 1.3396.
# Epoch 487/500 Iteration 99240 | Training Loss: 1.3281.
# Epoch 487/500 Iteration 99250 | Training Loss: 1.3232.
# Epoch 487/500 Iteration 99260 | Training Loss: 1.3628.
# Epoch 487/500 Iteration 99270 | Training Loss: 1.3282.
# Epoch 487/500 Iteration 99280 | Training Loss: 1.3308.
# Epoch 487/500 Iteration 99290 | Training Loss: 1.3040.
# Epoch 487/500 Iteration 99300 | Training Loss: 1.3773.
# Epoch 487/500 Iteration 99310 | Training Loss: 1.3361.
# Epoch 487/500 Iteration 99320 | Training Loss: 1.3658.
# Epoch 487/500 Iteration 99330 | Training Loss: 1.3599.
# Epoch 487/500 Iteration 99340 | Training Loss: 1.4332.
# Epoch 488/500 Iteration 99350 | Training Loss: 1.3766.
# Epoch 488/500 Iteration 99360 | Training Loss: 1.3703.
# Epoch 488/500 Iteration 99370 | Training Loss: 1.3850.
# Epoch 488/500 Iteration 99380 | Training Loss: 1.3220.
# Epoch 488/500 Iteration 99390 | Training Loss: 1.3438.
# Epoch 488/500 Iteration 99400 | Training Loss: 1.3511.
# Epoch 488/500 Iteration 99410 | Training Loss: 1.3325.
# Epoch 488/500 Iteration 99420 | Training Loss: 1.3191.
# Epoch 488/500 Iteration 99430 | Training Loss: 1.3798.
# Epoch 488/500 Iteration 99440 | Training Loss: 1.3375.
# Epoch 488/500 Iteration 99450 | Training Loss: 1.3057.
# Epoch 488/500 Iteration 99460 | Training Loss: 1.3110.
# Epoch 488/500 Iteration 99470 | Training Loss: 1.3320.
# Epoch 488/500 Iteration 99480 | Training Loss: 1.3028.
# Epoch 488/500 Iteration 99490 | Training Loss: 1.3113.
# Epoch 488/500 Iteration 99500 | Training Loss: 1.3187.
# Epoch 488/500 Iteration 99510 | Training Loss: 1.3886.
# Epoch 488/500 Iteration 99520 | Training Loss: 1.3464.
# Epoch 488/500 Iteration 99530 | Training Loss: 1.3486.
# Epoch 488/500 Iteration 99540 | Training Loss: 1.3676.
# Epoch 488/500 Iteration 99550 | Training Loss: 1.3895.
# Epoch 489/500 Iteration 99560 | Training Loss: 1.3367.
# Epoch 489/500 Iteration 99570 | Training Loss: 1.2717.
# Epoch 489/500 Iteration 99580 | Training Loss: 1.3525.
# Epoch 489/500 Iteration 99590 | Training Loss: 1.3316.
# Epoch 489/500 Iteration 99600 | Training Loss: 1.4330.
# Epoch 489/500 Iteration 99610 | Training Loss: 1.3488.
# Epoch 489/500 Iteration 99620 | Training Loss: 1.3593.
# Epoch 489/500 Iteration 99630 | Training Loss: 1.3829.
# Epoch 489/500 Iteration 99640 | Training Loss: 1.3521.
# Epoch 489/500 Iteration 99650 | Training Loss: 1.3360.
# Epoch 489/500 Iteration 99660 | Training Loss: 1.3359.
# Epoch 489/500 Iteration 99670 | Training Loss: 1.2907.
# Epoch 489/500 Iteration 99680 | Training Loss: 1.3498.
# Epoch 489/500 Iteration 99690 | Training Loss: 1.3425.
# Epoch 489/500 Iteration 99700 | Training Loss: 1.3011.
# Epoch 489/500 Iteration 99710 | Training Loss: 1.3547.
# Epoch 489/500 Iteration 99720 | Training Loss: 1.3382.
# Epoch 489/500 Iteration 99730 | Training Loss: 1.3491.
# Epoch 489/500 Iteration 99740 | Training Loss: 1.3323.
# Epoch 489/500 Iteration 99750 | Training Loss: 1.3475.
# Epoch 490/500 Iteration 99760 | Training Loss: 1.3735.
# Epoch 490/500 Iteration 99770 | Training Loss: 1.3229.
# Epoch 490/500 Iteration 99780 | Training Loss: 1.3713.
# Epoch 490/500 Iteration 99790 | Training Loss: 1.3377.
# Epoch 490/500 Iteration 99800 | Training Loss: 1.3416.
# Epoch 490/500 Iteration 99810 | Training Loss: 1.3704.
# Epoch 490/500 Iteration 99820 | Training Loss: 1.3448.
# Epoch 490/500 Iteration 99830 | Training Loss: 1.3582.
# Epoch 490/500 Iteration 99840 | Training Loss: 1.3354.
# Epoch 490/500 Iteration 99850 | Training Loss: 1.3126.
# Epoch 490/500 Iteration 99860 | Training Loss: 1.3195.
# Epoch 490/500 Iteration 99870 | Training Loss: 1.3490.
# Epoch 490/500 Iteration 99880 | Training Loss: 1.3540.
# Epoch 490/500 Iteration 99890 | Training Loss: 1.3527.
# Epoch 490/500 Iteration 99900 | Training Loss: 1.2993.
# Epoch 490/500 Iteration 99910 | Training Loss: 1.3529.
# Epoch 490/500 Iteration 99920 | Training Loss: 1.3488.
# Epoch 490/500 Iteration 99930 | Training Loss: 1.3865.
# Epoch 490/500 Iteration 99940 | Training Loss: 1.3390.
# Epoch 490/500 Iteration 99950 | Training Loss: 1.3317.
# Epoch 490/500 Iteration 99960 | Training Loss: 1.3792.
# Epoch 491/500 Iteration 99970 | Training Loss: 1.3469.
# Epoch 491/500 Iteration 99980 | Training Loss: 1.3270.
# Epoch 491/500 Iteration 99990 | Training Loss: 1.3266.
# Epoch 491/500 Iteration 100000 | Training Loss: 1.3727.
# Epoch 491/500 Iteration 100010 | Training Loss: 1.3275.
# Epoch 491/500 Iteration 100020 | Training Loss: 1.3637.
# Epoch 491/500 Iteration 100030 | Training Loss: 1.3626.
# Epoch 491/500 Iteration 100040 | Training Loss: 1.3047.
# Epoch 491/500 Iteration 100050 | Training Loss: 1.3478.
# Epoch 491/500 Iteration 100060 | Training Loss: 1.3430.
# Epoch 491/500 Iteration 100070 | Training Loss: 1.2893.
# Epoch 491/500 Iteration 100080 | Training Loss: 1.3321.
# Epoch 491/500 Iteration 100090 | Training Loss: 1.3206.
# Epoch 491/500 Iteration 100100 | Training Loss: 1.3389.
# Epoch 491/500 Iteration 100110 | Training Loss: 1.3405.
# Epoch 491/500 Iteration 100120 | Training Loss: 1.3789.
# Epoch 491/500 Iteration 100130 | Training Loss: 1.3385.
# Epoch 491/500 Iteration 100140 | Training Loss: 1.3673.
# Epoch 491/500 Iteration 100150 | Training Loss: 1.3538.
# Epoch 491/500 Iteration 100160 | Training Loss: 1.3618.
# Epoch 492/500 Iteration 100170 | Training Loss: 1.3602.
# Epoch 492/500 Iteration 100180 | Training Loss: 1.3593.
# Epoch 492/500 Iteration 100190 | Training Loss: 1.3128.
# Epoch 492/500 Iteration 100200 | Training Loss: 1.3269.
# Epoch 492/500 Iteration 100210 | Training Loss: 1.3391.
# Epoch 492/500 Iteration 100220 | Training Loss: 1.3142.
# Epoch 492/500 Iteration 100230 | Training Loss: 1.3435.
# Epoch 492/500 Iteration 100240 | Training Loss: 1.3530.
# Epoch 492/500 Iteration 100250 | Training Loss: 1.3565.
# Epoch 492/500 Iteration 100260 | Training Loss: 1.3313.
# Epoch 492/500 Iteration 100270 | Training Loss: 1.3289.
# Epoch 492/500 Iteration 100280 | Training Loss: 1.3631.
# Epoch 492/500 Iteration 100290 | Training Loss: 1.3428.
# Epoch 492/500 Iteration 100300 | Training Loss: 1.3421.
# Epoch 492/500 Iteration 100310 | Training Loss: 1.3089.
# Epoch 492/500 Iteration 100320 | Training Loss: 1.3721.
# Epoch 492/500 Iteration 100330 | Training Loss: 1.3505.
# Epoch 492/500 Iteration 100340 | Training Loss: 1.3668.
# Epoch 492/500 Iteration 100350 | Training Loss: 1.3763.
# Epoch 492/500 Iteration 100360 | Training Loss: 1.4093.
# Epoch 493/500 Iteration 100370 | Training Loss: 1.3819.
# Epoch 493/500 Iteration 100380 | Training Loss: 1.3838.
# Epoch 493/500 Iteration 100390 | Training Loss: 1.3889.
# Epoch 493/500 Iteration 100400 | Training Loss: 1.3075.
# Epoch 493/500 Iteration 100410 | Training Loss: 1.3468.
# Epoch 493/500 Iteration 100420 | Training Loss: 1.3494.
# Epoch 493/500 Iteration 100430 | Training Loss: 1.3267.
# Epoch 493/500 Iteration 100440 | Training Loss: 1.3413.
# Epoch 493/500 Iteration 100450 | Training Loss: 1.3776.
# Epoch 493/500 Iteration 100460 | Training Loss: 1.3420.
# Epoch 493/500 Iteration 100470 | Training Loss: 1.2937.
# Epoch 493/500 Iteration 100480 | Training Loss: 1.3088.
# Epoch 493/500 Iteration 100490 | Training Loss: 1.3363.
# Epoch 493/500 Iteration 100500 | Training Loss: 1.2971.
# Epoch 493/500 Iteration 100510 | Training Loss: 1.3201.
# Epoch 493/500 Iteration 100520 | Training Loss: 1.3218.
# Epoch 493/500 Iteration 100530 | Training Loss: 1.3801.
# Epoch 493/500 Iteration 100540 | Training Loss: 1.3290.
# Epoch 493/500 Iteration 100550 | Training Loss: 1.3372.
# Epoch 493/500 Iteration 100560 | Training Loss: 1.3680.
# Epoch 493/500 Iteration 100570 | Training Loss: 1.3856.
# Epoch 494/500 Iteration 100580 | Training Loss: 1.3524.
# Epoch 494/500 Iteration 100590 | Training Loss: 1.2745.
# Epoch 494/500 Iteration 100600 | Training Loss: 1.3358.
# Epoch 494/500 Iteration 100610 | Training Loss: 1.3315.
# Epoch 494/500 Iteration 100620 | Training Loss: 1.4162.
# Epoch 494/500 Iteration 100630 | Training Loss: 1.3404.
# Epoch 494/500 Iteration 100640 | Training Loss: 1.3599.
# Epoch 494/500 Iteration 100650 | Training Loss: 1.3801.
# Epoch 494/500 Iteration 100660 | Training Loss: 1.3481.
# Epoch 494/500 Iteration 100670 | Training Loss: 1.3455.
# Epoch 494/500 Iteration 100680 | Training Loss: 1.3462.
# Epoch 494/500 Iteration 100690 | Training Loss: 1.2918.
# Epoch 494/500 Iteration 100700 | Training Loss: 1.3515.
# Epoch 494/500 Iteration 100710 | Training Loss: 1.3394.
# Epoch 494/500 Iteration 100720 | Training Loss: 1.3025.
# Epoch 494/500 Iteration 100730 | Training Loss: 1.3484.
# Epoch 494/500 Iteration 100740 | Training Loss: 1.3396.
# Epoch 494/500 Iteration 100750 | Training Loss: 1.3437.
# Epoch 494/500 Iteration 100760 | Training Loss: 1.3148.
# Epoch 494/500 Iteration 100770 | Training Loss: 1.3605.
# Epoch 495/500 Iteration 100780 | Training Loss: 1.3777.
# Epoch 495/500 Iteration 100790 | Training Loss: 1.3401.
# Epoch 495/500 Iteration 100800 | Training Loss: 1.3653.
# Epoch 495/500 Iteration 100810 | Training Loss: 1.3350.
# Epoch 495/500 Iteration 100820 | Training Loss: 1.3237.
# Epoch 495/500 Iteration 100830 | Training Loss: 1.3778.
# Epoch 495/500 Iteration 100840 | Training Loss: 1.3372.
# Epoch 495/500 Iteration 100850 | Training Loss: 1.3356.
# Epoch 495/500 Iteration 100860 | Training Loss: 1.3396.
# Epoch 495/500 Iteration 100870 | Training Loss: 1.3220.
# Epoch 495/500 Iteration 100880 | Training Loss: 1.3198.
# Epoch 495/500 Iteration 100890 | Training Loss: 1.3260.
# Epoch 495/500 Iteration 100900 | Training Loss: 1.3457.
# Epoch 495/500 Iteration 100910 | Training Loss: 1.3611.
# Epoch 495/500 Iteration 100920 | Training Loss: 1.3033.
# Epoch 495/500 Iteration 100930 | Training Loss: 1.3388.
# Epoch 495/500 Iteration 100940 | Training Loss: 1.3411.
# Epoch 495/500 Iteration 100950 | Training Loss: 1.3765.
# Epoch 495/500 Iteration 100960 | Training Loss: 1.3381.
# Epoch 495/500 Iteration 100970 | Training Loss: 1.3077.
# Epoch 495/500 Iteration 100980 | Training Loss: 1.3802.
# Epoch 496/500 Iteration 100990 | Training Loss: 1.3511.
# Epoch 496/500 Iteration 101000 | Training Loss: 1.3195.
# Epoch 496/500 Iteration 101010 | Training Loss: 1.3165.
# Epoch 496/500 Iteration 101020 | Training Loss: 1.3763.
# Epoch 496/500 Iteration 101030 | Training Loss: 1.3279.
# Epoch 496/500 Iteration 101040 | Training Loss: 1.3522.
# Epoch 496/500 Iteration 101050 | Training Loss: 1.3462.
# Epoch 496/500 Iteration 101060 | Training Loss: 1.3051.
# Epoch 496/500 Iteration 101070 | Training Loss: 1.3308.
# Epoch 496/500 Iteration 101080 | Training Loss: 1.3454.
# Epoch 496/500 Iteration 101090 | Training Loss: 1.2979.
# Epoch 496/500 Iteration 101100 | Training Loss: 1.3328.
# Epoch 496/500 Iteration 101110 | Training Loss: 1.3244.
# Epoch 496/500 Iteration 101120 | Training Loss: 1.3496.
# Epoch 496/500 Iteration 101130 | Training Loss: 1.3424.
# Epoch 496/500 Iteration 101140 | Training Loss: 1.3740.
# Epoch 496/500 Iteration 101150 | Training Loss: 1.3398.
# Epoch 496/500 Iteration 101160 | Training Loss: 1.3677.
# Epoch 496/500 Iteration 101170 | Training Loss: 1.3512.
# Epoch 496/500 Iteration 101180 | Training Loss: 1.3581.
# Epoch 497/500 Iteration 101190 | Training Loss: 1.3619.
# Epoch 497/500 Iteration 101200 | Training Loss: 1.3575.
# Epoch 497/500 Iteration 101210 | Training Loss: 1.3273.
# Epoch 497/500 Iteration 101220 | Training Loss: 1.3299.
# Epoch 497/500 Iteration 101230 | Training Loss: 1.3431.
# Epoch 497/500 Iteration 101240 | Training Loss: 1.3249.
# Epoch 497/500 Iteration 101250 | Training Loss: 1.3229.
# Epoch 497/500 Iteration 101260 | Training Loss: 1.3627.
# Epoch 497/500 Iteration 101270 | Training Loss: 1.3417.
# Epoch 497/500 Iteration 101280 | Training Loss: 1.3333.
# Epoch 497/500 Iteration 101290 | Training Loss: 1.3186.
# Epoch 497/500 Iteration 101300 | Training Loss: 1.3731.
# Epoch 497/500 Iteration 101310 | Training Loss: 1.3157.
# Epoch 497/500 Iteration 101320 | Training Loss: 1.3391.
# Epoch 497/500 Iteration 101330 | Training Loss: 1.2862.
# Epoch 497/500 Iteration 101340 | Training Loss: 1.3616.
# Epoch 497/500 Iteration 101350 | Training Loss: 1.3315.
# Epoch 497/500 Iteration 101360 | Training Loss: 1.3690.
# Epoch 497/500 Iteration 101370 | Training Loss: 1.3594.
# Epoch 497/500 Iteration 101380 | Training Loss: 1.4113.
# Epoch 498/500 Iteration 101390 | Training Loss: 1.3791.
# Epoch 498/500 Iteration 101400 | Training Loss: 1.3796.
# Epoch 498/500 Iteration 101410 | Training Loss: 1.3840.
# Epoch 498/500 Iteration 101420 | Training Loss: 1.3177.
# Epoch 498/500 Iteration 101430 | Training Loss: 1.3560.
# Epoch 498/500 Iteration 101440 | Training Loss: 1.3530.
# Epoch 498/500 Iteration 101450 | Training Loss: 1.3153.
# Epoch 498/500 Iteration 101460 | Training Loss: 1.3300.
# Epoch 498/500 Iteration 101470 | Training Loss: 1.3783.
# Epoch 498/500 Iteration 101480 | Training Loss: 1.3414.
# Epoch 498/500 Iteration 101490 | Training Loss: 1.2921.
# Epoch 498/500 Iteration 101500 | Training Loss: 1.3001.
# Epoch 498/500 Iteration 101510 | Training Loss: 1.3395.
# Epoch 498/500 Iteration 101520 | Training Loss: 1.3166.
# Epoch 498/500 Iteration 101530 | Training Loss: 1.3262.
# Epoch 498/500 Iteration 101540 | Training Loss: 1.3237.
# Epoch 498/500 Iteration 101550 | Training Loss: 1.3801.
# Epoch 498/500 Iteration 101560 | Training Loss: 1.3331.
# Epoch 498/500 Iteration 101570 | Training Loss: 1.3431.
# Epoch 498/500 Iteration 101580 | Training Loss: 1.3715.
# Epoch 498/500 Iteration 101590 | Training Loss: 1.3893.
# Epoch 499/500 Iteration 101600 | Training Loss: 1.3427.
# Epoch 499/500 Iteration 101610 | Training Loss: 1.2682.
# Epoch 499/500 Iteration 101620 | Training Loss: 1.3559.
# Epoch 499/500 Iteration 101630 | Training Loss: 1.3384.
# Epoch 499/500 Iteration 101640 | Training Loss: 1.4226.
# Epoch 499/500 Iteration 101650 | Training Loss: 1.3553.
# Epoch 499/500 Iteration 101660 | Training Loss: 1.3556.
# Epoch 499/500 Iteration 101670 | Training Loss: 1.3826.
# Epoch 499/500 Iteration 101680 | Training Loss: 1.3662.
# Epoch 499/500 Iteration 101690 | Training Loss: 1.3533.
# Epoch 499/500 Iteration 101700 | Training Loss: 1.3404.
# Epoch 499/500 Iteration 101710 | Training Loss: 1.2898.
# Epoch 499/500 Iteration 101720 | Training Loss: 1.3421.
# Epoch 499/500 Iteration 101730 | Training Loss: 1.3486.
# Epoch 499/500 Iteration 101740 | Training Loss: 1.2930.
# Epoch 499/500 Iteration 101750 | Training Loss: 1.3493.
# Epoch 499/500 Iteration 101760 | Training Loss: 1.3379.
# Epoch 499/500 Iteration 101770 | Training Loss: 1.3315.
# Epoch 499/500 Iteration 101780 | Training Loss: 1.3275.
# Epoch 499/500 Iteration 101790 | Training Loss: 1.3541.
# Epoch 500/500 Iteration 101800 | Training Loss: 1.3809.
# Epoch 500/500 Iteration 101810 | Training Loss: 1.3318.
# Epoch 500/500 Iteration 101820 | Training Loss: 1.3617.
# Epoch 500/500 Iteration 101830 | Training Loss: 1.3344.
# Epoch 500/500 Iteration 101840 | Training Loss: 1.3343.
# Epoch 500/500 Iteration 101850 | Training Loss: 1.3832.
# Epoch 500/500 Iteration 101860 | Training Loss: 1.3412.
# Epoch 500/500 Iteration 101870 | Training Loss: 1.3542.
# Epoch 500/500 Iteration 101880 | Training Loss: 1.3297.
# Epoch 500/500 Iteration 101890 | Training Loss: 1.3075.
# Epoch 500/500 Iteration 101900 | Training Loss: 1.3245.
# Epoch 500/500 Iteration 101910 | Training Loss: 1.3302.
# Epoch 500/500 Iteration 101920 | Training Loss: 1.3602.
# Epoch 500/500 Iteration 101930 | Training Loss: 1.3561.
# Epoch 500/500 Iteration 101940 | Training Loss: 1.3078.
# Epoch 500/500 Iteration 101950 | Training Loss: 1.3459.
# Epoch 500/500 Iteration 101960 | Training Loss: 1.3386.
# Epoch 500/500 Iteration 101970 | Training Loss: 1.3773.
# Epoch 500/500 Iteration 101980 | Training Loss: 1.3429.
# Epoch 500/500 Iteration 101990 | Training Loss: 1.3138.
# Epoch 500/500 Iteration 102000 | Training Loss: 1.3624.

# %% [markdown]
# ## The CharRNN model in the sampling mode
#
# Next up, we can create a new instance of the `CharRNN` class in the sampling mode by specifying that `sampling=True`.  We'll call the `sample` method to load the saved model in the `./model-250/` folder, and generate a sequence of 500 characters:

# %%
del rnn

np.random.seed(123)
rnn = CharRNN(len(chars), sampling=True)
print(rnn.sample(ckpt_dir="./model-500/", output_length=500))
# Out:
#   << lstm_outputs >> Tensor("rnn/transpose_1:0", shape=(1, 1, 128), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model-500/language_modeling.ckpt
# Men will ball to the person.
# The mind and saying. To an
# arrivel was his constantly he was till on the place at the cardinal, the stell tows the taken with his passess in the silenty and the thoughts stained on the service of suscetingen her secrece as he had shone is the partity with in that of the
# sare; the charmen would not the took were bucking that she and the procurator’s wife of the crime the post, steps that he had someone the cast at himself to having, and the memenon to the tapponessenss, we

# %% [markdown]
# The generated text will look like the following:
#
# <img src="images/16_15.png" style="width:500px">
#
# You can see that in the resulting output, that some English words are mostly preserved.  It's also important to note that this is from an old English text, therefore, some words in the original text may be unfamiliar.  To get a better result, we would need to train for higher number of epochs.  Feel free to repeat this with a much larger document and train the model for more epochs.
